# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Общая-информация" data-toc-modified-id="Общая-информация-1">Общая информация</a></span><ul class="toc-item"><li><span><a href="#Функции" data-toc-modified-id="Функции-1.1">Функции</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2">Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Преобразование-форматов" data-toc-modified-id="Преобразование-форматов-2.1">Преобразование форматов</a></span></li><li><span><a href="#Обзор-данных" data-toc-modified-id="Обзор-данных-2.2">Обзор данных</a></span></li><li><span><a href="#Пропуски-и-нулевые-значения" data-toc-modified-id="Пропуски-и-нулевые-значения-2.3">Пропуски и нулевые значения</a></span></li><li><span><a href="#Проверка-дубликатов" data-toc-modified-id="Проверка-дубликатов-2.4">Проверка дубликатов</a></span></li><li><span><a href="#Добавление-данных" data-toc-modified-id="Добавление-данных-2.5">Добавление данных</a></span></li><li><span><a href="#Объединение-таблиц" data-toc-modified-id="Объединение-таблиц-2.6">Объединение таблиц</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.7">Вывод</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3">Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Анализ-студентов-по-специализации" data-toc-modified-id="Анализ-студентов-по-специализации-3.1">Анализ студентов по специализации</a></span></li><li><span><a href="#Анализ-студентов-по-сегментам-оплаты-(B2B,-B2C,-B2G)" data-toc-modified-id="Анализ-студентов-по-сегментам-оплаты-(B2B,-B2C,-B2G)-3.2">Анализ студентов по сегментам оплаты (B2B, B2C, B2G)</a></span></li><li><span><a href="#Составление-портретов-студентов" data-toc-modified-id="Составление-портретов-студентов-3.3">Составление портретов студентов</a></span><ul class="toc-item"><li><span><a href="#Распределение-ответов-по-пользователям-в-целом" data-toc-modified-id="Распределение-ответов-по-пользователям-в-целом-3.3.1">Распределение ответов по пользователям в целом</a></span></li><li><span><a href="#Распределение-ответов-по-направления-обучения" data-toc-modified-id="Распределение-ответов-по-направления-обучения-3.3.2">Распределение ответов по направления обучения</a></span></li><li><span><a href="#Распределение-ответов-по-сегментам" data-toc-modified-id="Распределение-ответов-по-сегментам-3.3.3">Распределение ответов по сегментам</a></span></li></ul></li><li><span><a href="#Зависимость-целей-от-опыта" data-toc-modified-id="Зависимость-целей-от-опыта-3.4">Зависимость целей от опыта</a></span></li><li><span><a href="#Зависимость-опций-карьерной-поддержки-от-опыта" data-toc-modified-id="Зависимость-опций-карьерной-поддержки-от-опыта-3.5">Зависимость опций карьерной поддержки от опыта</a></span></li><li><span><a href="#Анализ-пользователей-по-уровням--learning-performance-и-уверенности-в-знаниях-content" data-toc-modified-id="Анализ-пользователей-по-уровням--learning-performance-и-уверенности-в-знаниях-content-3.6">Анализ пользователей по уровням  learning performance и уверенности в знаниях content</a></span><ul class="toc-item"><li><span><a href="#Анализ-пользователей-по-learning-performance" data-toc-modified-id="Анализ-пользователей-по-learning-performance-3.6.1">Анализ пользователей по learning performance</a></span></li><li><span><a href="#Анализ-пользователей-по-уверенности-в-знаниях" data-toc-modified-id="Анализ-пользователей-по-уверенности-в-знаниях-3.6.2">Анализ пользователей по уверенности в знаниях</a></span></li><li><span><a href="#Корреляция-между-learning-performance-и-уверенностью-студента-в-знаниях" data-toc-modified-id="Корреляция-между-learning-performance-и-уверенностью-студента-в-знаниях-3.6.3">Корреляция между learning performance и уверенностью студента в знаниях</a></span></li></ul></li><li><span><a href="#Зависимость-уровня-знаний-и-уверенности-студента-от-опыта-и-целей" data-toc-modified-id="Зависимость-уровня-знаний-и-уверенности-студента-от-опыта-и-целей-3.7">Зависимость уровня знаний и уверенности студента от опыта и целей</a></span></li></ul></li><li><span><a href="#Формирование-сегментов-в-зависимости-от-уровня-знаний-и-уверенности-студента-в-себе" data-toc-modified-id="Формирование-сегментов-в-зависимости-от-уровня-знаний-и-уверенности-студента-в-себе-4">Формирование сегментов в зависимости от уровня знаний и уверенности студента в себе</a></span><ul class="toc-item"><li><span><a href="#Проверка-статистических-гипотез" data-toc-modified-id="Проверка-статистических-гипотез-4.1">Проверка статистических гипотез</a></span></li><li><span><a href="#Распределение-направлений-обучения-среди-выделенных-сегментов" data-toc-modified-id="Распределение-направлений-обучения-среди-выделенных-сегментов-4.2">Распределение направлений обучения среди выделенных сегментов</a></span></li><li><span><a href="#Распределение-разного-вида-опыта-среди-выделенных-сегментов" data-toc-modified-id="Распределение-разного-вида-опыта-среди-выделенных-сегментов-4.3">Распределение разного вида опыта среди выделенных сегментов</a></span></li><li><span><a href="#Распределение-вариантов-карьерной-поддержки-среди-выделенных-сегментов" data-toc-modified-id="Распределение-вариантов-карьерной-поддержки-среди-выделенных-сегментов-4.4">Распределение вариантов карьерной поддержки среди выделенных сегментов</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Анализ целей обучения студентов Яндекс Практикума

# %% [markdown]
# ## Общая информация

# %% [markdown]
# В нашем распоряжении данные об ответах студентов на вопросы касающиеся целей обучения и метрики их знаний (субъективные и объективные)
# Необходимо проанализировать и выделить группы студентов, которым нужна помощь
#
# **Цели исследования:**
#  * определить нормальные и найти аномальные показатели
#  * определить коррелирующие параметры, построить портреты студентов, сравнить их, чтобы выделить значимые закономерности
#  * сегментировать студентов (по 2м и более показателям), выявить особенности сегментов
#  * сформулировать на основе данных гипотезы по улучшению выстраивания помощи студентам в достижении их целей
#
# **План исследования:**
#
#  * предобработка данных:
#  * исследовательский анализ данных:
#    * распределение ответов
#    * предварительное формирование сегментов покупателей
#    * окончательное формирование сегментов покупателей
#    * формирование гипотез и проверка статистической значимости между сегментами покупателей
#  * выводы

# %%
#pip install jenkspy

# %%
# импорт библиотек
import pandas as pd
from datetime import date
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats as st
from matplotlib.ticker import EngFormatter
import matplotlib.ticker as mtick
import warnings 
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 50)
pd.set_option('max_colwidth', 500)
import itertools
import jenkspy

# %%
# загрузка данных
try:
    answers = pd.read_csv('C:/Users/Admin/Downloads/data_goals_answers_fin.csv',index_col=0)
except:
    answers = pd.read_csv('https://raw.githubusercontent.com/KaterinaFrolkova/categories/main/data_goals_answers_fin.csv',index_col=0)

try:
    metrics = pd.read_csv(r'C:\Users\Admin\Downloads\hackathon_metrics.csv',index_col=0)
except:
    metrics = pd.read_csv('https://raw.githubusercontent.com/KaterinaFrolkova/categories/main/hackathon_metrics.csv',index_col=0)

# %% [markdown]
# **Общая информация о таблице с ответами**

# %%
answers.sample(3)
# Out:
#         user_id          answer_date                             answer_id  \
# 35484  14962363  2023-08-22 16:05:00  548b3540-89db-4cb4-a064-004e5e8df4e0
# 3111     456264  2023-07-20 08:47:00  6e23e356-43f1-4438-a8d5-67f6049f0587
# 9936    2713241  2023-09-19 11:20:00  366f5518-5b31-473e-af1e-15e068238b23
#
#                           cohort      course_name             current_cohort  \
# 35484            data_cohort_119  Трудоустройство            data_cohort_129
# 3111             data_cohort_111  Трудоустройство            data_cohort_119
# 9936   systems_analyst_cohort_13  Трудоустройство  systems_analyst_cohort_13
#
#       current_segment    lesson_name original_segment  profession_name  \
# 35484             b2c  Цель обучения              b2g     data-analyst
# 3111              b2c  Цель обучения              b2c     data-analyst
# 9936              b2c  Цель обучения              b2c  systems-analyst
#
#                                                                                                                                                                                            question_title  \
# 35484  В зависимости от опыта работы вам может понадобиться разный вид консультаций и помощи от команды сопровождения и трудоустройства. Для нас очень важен честный ответ и понимание вашего бэкграунда.
# 3111                                                                                               Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.
# 9936                                                                                               Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.
#
#       question_type  slide_position  statement_content       topic_name  \
# 35484         radio               0                NaN  Трудоустройство
# 3111       checkbox               0                NaN  Трудоустройство
# 9936       checkbox               0                NaN  Трудоустройство
#
#                                                   user_answer
# 35484  От 1 до 3 лет опыта работы направлении Анализа данных.
# 3111                         оценка шансов на трудоустройство
# 9936                                 решение тестовых заданий

# %%
answers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43428 entries, 1 to 43428
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            43428 non-null  int64
#  1   answer_date        43428 non-null  object
#  2   answer_id          43428 non-null  object
#  3   cohort             43428 non-null  object
#  4   course_name        43428 non-null  object
#  5   current_cohort     43428 non-null  object
#  6   current_segment    43223 non-null  object
#  7   lesson_name        43428 non-null  object
#  8   original_segment   43223 non-null  object
#  9   profession_name    43428 non-null  object
#  10  question_title     43428 non-null  object
#  11  question_type      43428 non-null  object
#  12  slide_position     43428 non-null  int64
#  13  statement_content  0 non-null      float64
#  14  topic_name         43428 non-null  object
#  15  user_answer        43417 non-null  object
# dtypes: float64(1), int64(2), object(13)
# memory usage: 5.6+ MB

# %% [markdown]
# **Описание данных**
#
# * `user_id` — уникальный id пользователя
# * `answer_date` — время ответа
# * `answer_id` — id ответа
# * `cohort` — начальная когорта студента
# * `current_cohort` — текущая когорта студента
# * `original_segment, current_segment` — b2c/b2b/b2g — из какого сегмента был/стал студент — сам является клиентом, его обучение оплачивается бизнесом или государством
# * `course_name, topic_name` — курс и тема, на котором студент отвечает на вопрос, в нашем случае `Трудоустройство`
# * `lesson_name` — урок, на котором студент отвечает на вопрос, в нашем случае `Цель обучения`
# * `profession_name` — код профессии
# * `question_title` — текст вопроса
# * `question_type` — тип вопроса
# * `slide_position` — страница опроса (не нужно для анализа)
# * `statement_content` — формулировка вопроса об уверенности в знаниях (в этой таблице не заполнено)
# * `user_answer` — ответ пользователя на вопрос

# %% [markdown]
# **Общая информация о таблице с метриками студентов**

# %%
metrics.sample(5)
# Out:
#       profession_name   user_id  lp_avg_user  \
# 24229    data-analyst   9395979     0.572727
# 64033    data-analyst   2306995     0.770000
# 20140    data-analyst  15164817     0.620000
# 76904    data-analyst   4326553     0.679091
# 1796   data-scientist  14184386     0.657778
#
#                                                                                statement_content  \
# 24229  Моя уверенность в своих знаниях значительно повысилась по сравнению с предыдущим спринтом
# 64033  Моя уверенность в своих знаниях значительно повысилась по сравнению с предыдущим спринтом
# 20140  Моя уверенность в своих знаниях значительно повысилась по сравнению с предыдущим спринтом
# 76904  Моя уверенность в своих знаниях значительно повысилась по сравнению с предыдущим спринтом
# 1796   Моя уверенность в своих знаниях значительно повысилась по сравнению с предыдущим спринтом
#
#        value  \
# 24229      2
# 64033     -1
# 20140     -1
# 76904      1
# 1796       2
#
#                                                                                                                                                  question_title  \
# 24229                                                                                                                                                       NaN
# 64033                                                                                                                                                       NaN
# 20140                                                                                                                                                       NaN
# 76904  Какова вероятность, что вы порекомендуете Практикум своим друзьям по шкале от 0 до 10, где 10 — обязательно порекомендую, 0 — не порекомендую ни за что?
# 1796                                                                                                                                                        NaN
#
#        user_answer
# 24229          NaN
# 64033          NaN
# 20140          NaN
# 76904         10.0
# 1796           NaN

# %%
metrics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 79117 entries, 0 to 79116
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   profession_name    79117 non-null  object
#  1   user_id            79117 non-null  int64
#  2   lp_avg_user        79117 non-null  float64
#  3   statement_content  79117 non-null  object
#  4   value              79117 non-null  int64
#  5   question_title     14739 non-null  object
#  6   user_answer        14739 non-null  float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 4.8+ MB

# %% [markdown]
# **Описание данных**
# * `profession_name` — код профессии
# * `user_id` — уникальный id пользователя
# * `lp_avg_user` — средний learning performance — оценка того, как хорошо студент справляется (по данным Практикума), от 0 до 1
# * `statement_content` — формулировка вопроса об уверенности в знаниях студента
# * `value` — ответ студента на вопрос об уверенности в знаниях для расчёта learning experience индекса, от -2 до 2
# * `question_title` — текст вопроса о рекомендации Практикума свом друзьям
# * `user_answer` — ответ пользователя этот вопрос
#
# Известно, что данные об оценках даны в разрезе нескольких периодов, данные отсортированы от более старых дат к более новым.

# %% [markdown]
# Распределение уникальных значений в таблицах

# %%
answers.nunique()
# Out:
# user_id               3549
# answer_date           7882
# answer_id            14094
# cohort                 169
# course_name              1
# current_cohort         173
# current_segment          3
# lesson_name              1
# original_segment         3
# profession_name         11
# question_title           6
# question_type            3
# slide_position           2
# statement_content        0
# topic_name               1
# user_answer           1102
# dtype: int64

# %%
metrics.nunique()
# Out:
# profession_name        10
# user_id              9797
# lp_avg_user          3574
# statement_content       1
# value                   5
# question_title          1
# user_answer            11
# dtype: int64

# %% [markdown]
# ### Функции

# %%
def review (length, height, y, x, data, bins=50,rotation=0):
    plt.figure(figsize = (length, height))
    title_set = 0
    seria = 1
    plt.subplots_adjust(hspace = 0.3)

    for n in name:
        ax = plt.subplot(y, x, seria)
        sns.histplot(data[~data[n].isnull()][n], bins=bins,ax = ax, color = '#80b1d3')
        plt.ylabel("частота",size = 12)
        plt.xlabel("значение",size = 12)
        plt.xticks(rotation=rotation)
        plt.title(title[title_set], size =20);
        seria +=1
        title_set +=1
    plt.tight_layout()
    plt.show();

# %%
def zeros (name):
    for i in name.columns.tolist():
        print(i,len(name[name[i]==0]))

# %%
def barchart (length, height, data, x, y, palette, title, xlabel, ylabel, despinet, despiner, despinel, despineb, n, m=1, 
            horizont=True, perc_frmt=False, set_xticks=False, set_yticks=True, order=None, ylim=None, hue=None, edgecolor=None,
             k=False):
    
    # размеры
    plt.figure(figsize=(length, height))
    # график
    ax = sns.barplot(data = data, x=x, y=y, dodge=False, palette = palette, order=order, hue = hue, edgecolor=edgecolor)
    # название
    ax.axes.set_title(title, size = 20)
    # подпись ось x
    ax.set_xlabel(xlabel)
    # подпись ось y
    ax.set_ylabel(ylabel)
    # размер подпсиси
    ax.tick_params(labelsize=10) 
    # края графика
    sns.despine(top=despinet, right=despiner, left=despinel, bottom=despineb)
    
    # подписи
    #горизонтальный чарт
    if horizont==1:
        if perc_frmt==1:
            # процентная шкала
            ax.xaxis.set_major_formatter(mtick.PercentFormatter())
            # подписи данных в процентах
            for p in ax.patches:
                ax.annotate(f"{p.get_width():.{n}f}%", (p.get_width(), p.get_y()+p.get_height()/2),
                    xytext=(5, 0), textcoords='offset points', ha="left", va="center", fontsize=12)       
        else:
            if k==0:
                # подписи данных не в процентах 
                for p in ax.patches:
                    ax.annotate(f"{p.get_width()/m:.{n}f}", (p.get_width(), p.get_y() + p.get_height() / 2),
                        xytext=(5, 0),textcoords='offset points', ha='left', va='center', fontsize=12)
            else:
                # подписи данных не в процентах и с K
                for p in ax.patches:
                    ax.annotate(f"{p.get_width()/m:.{n}f}K", (p.get_width(), p.get_y() + p.get_height() / 2),
                        xytext=(5, 0),textcoords='offset points', ha='left', va='center', fontsize=12)
                
    # вертикальный чарт            
    else:
        if perc_frmt==1:
            # процентная шкала
            ax.xaxis.set_major_formatter(mtick.PercentFormatter())
            # подписи данных в процентах
            for p in ax.patches:
                ax.annotate(f"{p.get_height():.{n}f}%", (p.get_x() + p.get_width() / 2, p.get_height()),
                xytext=(0, 8),textcoords='offset points', ha='center', va='center', fontsize=12)    
        else:
            # подписи данных не в процентах 
            for p in ax.patches:
                ax.annotate(f"{p.get_height()/m:.{n}f}", (p.get_x() + p.get_width() / 2, p.get_height()),
                xytext=(0, 8),textcoords='offset points', ha='center', va='center', fontsize=12)            
    # ограничение
    ax.set_ylim(ylim)
    
    # отсутствие оси x       
    if set_xticks == 0:
        ax.set_xticks([])
        
    # отсутствие оси y       
    if set_yticks == 0:
        ax.set_yticks([]);

# %%
def doughnut (length, height, data, colors, n, title, labels, counterclock=True, color='b'):
    # размер
    plt.figure(figsize=(length, height))
    # строим пирог
    plt.pie(data, colors=colors, startangle=90,counterclock=counterclock\
            , autopct=lambda p:f'{p:.{n}f}%', textprops={'fontsize': 12, 'color':color}\
            , pctdistance=0.85)
    # центр
    centre_circle = plt.Circle((0, 0), 0.60, fc='white')
    fig = plt.gcf()
    # добавляем центр
    fig.gca().add_artist(centre_circle)
    # название
    plt.title(title, size =20)
    # легенда
    plt.legend(labels=labels, bbox_to_anchor=(1, 0.95), loc='upper left')
    plt.show()
    #plt.savefig(f"{title}.svg",format="svg")

# %%
def barh (data, length, height, palette, title, xlabel, ylabel, despinet, despiner, despinel, despineb, 
            n, perc_frmt=False, set_xticks=False, legend=False, legend_text=[], stacked=True, width = 0.75):
    # график
    ax = data.plot(figsize=(length, height), color = palette, kind='barh', stacked=stacked, width = width)
    # название
    ax.axes.set_title(title, size = 20)
    # подпись ось x
    ax.set_xlabel(xlabel)
    # подпись ось y
    ax.set_ylabel(ylabel)
    # легенда
    if legend==1:
        plt.legend(labels=legend_text, bbox_to_anchor=(1, 1), loc='best')
    # размер подпсиси
    ax.tick_params(labelsize=12) 
    # края графика
    sns.despine(top=despinet, right=despiner, left=despinel, bottom=despineb)

    if perc_frmt==1:
        # процентная шкала
        ax.xaxis.set_major_formatter(mtick.PercentFormatter())
        # подписи данных в процентах
        for p in ax.patches:
            if p.get_width()>0:
                label_text = f"{p.get_width():.{n}f}%"
            else:
                label_text = ''
        
            label_x = p.get_x() + p.get_width() / 2
            label_y = p.get_y() + p.get_height() / 2
            ax.text(label_x, label_y, label_text, ha='center', va='center', fontsize=10)              
    else:
        # подписи данных не в процентах 
        for p in ax.patches:
            if p.get_width()>0:
                label_text = f"{p.get_width():.{n}f}"
            else:
                label_text = ''
        
            label_x = p.get_x() + p.get_width() / 2
            label_y = p.get_y() + p.get_height() / 2
            ax.text(label_x, label_y, label_text, ha='center', va='center', fontsize=10)
    
    # отсутствие оси x       
    if set_xticks == 0:
        ax.set_xticks([])
    plt.show();

# %%
def viz_multiply(param, dict_title, data_1, data_2, data_3, position_opt):
  counter = 1
  for key, value in dict_title.items():
      if counter != position_opt:
        print(25*'-'+ f'{key.upper()}'+' ДЛЯ '+f'{param.upper()}'+25*'-')
        cnt_goals = (
             data_1[[param,'user_id',f'{key}']]
             .pivot_table(index=param,
                          columns=f'{key}',
                          values='user_id',
                          aggfunc='count')
              )
        cnt_goals_prct = cnt_goals.copy()
        cols = cnt_goals.columns.values
        cnt_goals_prct[cols] = (
              cnt_goals_prct[cols]
              .div(cnt_goals_prct[cols]
                  .sum(axis=1), axis=0)
              .multiply(100)
              )
        order = data_2[data_2['question']==f'{key}']['user_answer'][::-1]
        cnt_goals_prct = cnt_goals_prct.reindex(columns=order)
        cnt_goals_prct = cnt_goals_prct.sort_values(by=cnt_goals_prct.columns[0])
        #display(cnt_goals_prct)
        #визуализируем
        barh (cnt_goals_prct, 12, 8,colors,
                f'{value} \n', 'доли', 
                '', 1, 1, 1, 1, 0,perc_frmt= 1,
                legend=1, legend_text=order)
        counter +=1
      else:
          print(25*'-'+ f'{key.upper()}'+' ДЛЯ '+f'{param.upper()}'+25*'-')
          cnt_help = (
              data_3[data_3['question']==f'{key}']
              .pivot_table(index=param,
                          columns='user_answer',
                          values='user_id',
                          aggfunc='nunique')
              )
          cnt_help_prct = cnt_help.copy()
          cols = cnt_help.columns.values
          cnt_help_prct[cols] = (
              cnt_help_prct[cols]
              .div(cnt_help_prct[cols]
                  .sum(axis=1), axis=0)
              .multiply(100)
              )
          order = data_2[data_2['question']==f'{key}']['user_answer'][::-1]
          cnt_help_prct = cnt_help_prct.reindex(columns=order)
          cnt_help_prct = cnt_help_prct.sort_values(by=cnt_help_prct.columns[0])
          #display(cnt_help_prct)
          #визуализируем
          barh (cnt_help_prct, 12, 8, colors,f'{value}  \n',
                'Доли', '', 1, 1, 1, 1, 0,
                perc_frmt= 1, legend=1, 
                legend_text=order)
          counter += 1

# %%
def heatmapCr(data, title, xlabel, ylabel, figsize=(10, 10), fontsize=None, cmap='Blues', annot=True, 
              cbar=False, linewidths=5, linecolor='white', fmt=None, vmin=None, vmax=None):
    plt.figure(figsize=figsize)
    sns.heatmap(data, cmap=cmap, annot=annot, cbar=cbar, 
                linewidths=linewidths, linecolor=linecolor, fmt=fmt, vmin=vmin)
    plt.title(f'{title} \n', fontsize=fontsize)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show();

# %%
# функция для теста Манна Уитни
def test_mwu_update(value, p_list, name_list):
    all_group = (
      [list(j) for i in range(len(np.sort(data['pc_score'].unique()))) 
      for j in itertools.combinations(np.sort(data['pc_score'].unique()) , i+1)]
      )
    test_group = [i for i in all_group if len(i) == 2]
    alpha =0.05
    for uniq in test_group:
        gr_1 = data[data['pc_score']==uniq[0]][value]
        gr_2 = data[data['pc_score']==uniq[1]][value]
        name = f'gr_{uniq[0]}_'+ f'gr_{uniq[1]}'
        results = st.mannwhitneyu(
        gr_1, gr_2)
        p_list.append(results.pvalue)
        name_list.append(name)
        print('Гипотезы. \n')
        print(f'H0 - Между gr_{uniq[0]} и gr_{uniq[1]} статистически значимого отличия нет.')
        print(f'H1 - Между gr_{uniq[0]} и gr_{uniq[1]} есть статистически значимая разница.')
        print(' \n')
        print('alpha: {:.3f}'.format (alpha))
        print(f'Среднее первой группы gr_{uniq[0]} : '+'{:.3f}'.format (gr_1.mean()))
        print(f'Среднее второй группы gr_{uniq[1]} : '+'{:.3f}'.format (gr_2.mean()))
        print('results.pvalue: {:.5f}'.format (results.pvalue))
        print(60*'-')

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Преобразование форматов

# %%
answers['answer_date'] = pd.to_datetime(answers['answer_date'])

# %% [markdown]
# ### Обзор данных

# %% [markdown]
# **Таблица `answers`**

# %%
name = ['answer_date', 'current_segment', 'original_segment', 'profession_name'\
        , 'question_type']
title = ['answer_date', 'current_segment', 'original_segment', 'profession_name'\
        , 'question_type']
review (15,10, 2, 3, answers,rotation=70)

# %% [markdown]
# В таблице с ответами данные предоставлены за три месяца - июль 2023-сентябрь 2023, выбивающихся дат нет
# Распределение по сегментам - B2C и B2G примерно 50/50, сегмент B2B представлен мало
# По окончании обучения у некоторых сегмент B2G меняется на B2C, возможно это связано с тем, что студент не укладывается в сроки и продолжает обучение за свой счет.
# В датасете 11 профессий, в основном это DA и DS, на третьем месте системные аналитики, остальные группы это более точечные направления.
# Вопросы представлены тремя типами - чекбокс, radio- выбор одного варианта из нескольких и открытый текстовый ответ.

# %% [markdown]
# **Таблица `metrics`**

# %%
name = ['profession_name', 'lp_avg_user', 'value', 'user_answer']
title = ['profession_name', 'lp_avg_user', 'value', 'user_answer']
review (15,10, 2, 2, metrics,rotation=70)

# %% [markdown]
# В датасете 10 профессий, в основном это DA и DS, на третьем месте системные аналитики, остальные группы это более точечные направления.
# Оценка `средний learning performance` распределена от 0 до 1, без выбросов и аномальных значений.
# Распределение ассиметрично, скошено влево. Самые распространенные оценки 0.7-0.8. Нужно учесть,что оценки в датасете повторяются для одного и того же студента.
# Оценки на вопрос об уверенности студена в собственных знаниях распределена от-2 до 2, Большая чачть ответов это 1 и 2.
# Ответы на вопрос о рекомендации рапсределены от 0 до 10, большая часть ответов это оценка 10.

# %% [markdown]
# ### Пропуски и нулевые значения

# %%
spisok = ['answers','metrics']

# %% [markdown]
# **Пропуски**

# %%
for table_name in spisok:
    table = eval(table_name)
    null_counts = table.isna().sum()
    print('\n' + table_name + ':')
    print(null_counts)
# Out:
# answers:
# user_id                  0
# answer_date              0
# answer_id                0
# cohort                   0
# course_name              0
# current_cohort           0
# current_segment        205
# lesson_name              0
# original_segment       205
# profession_name          0
# question_title           0
# question_type            0
# slide_position           0
# statement_content    43428
# topic_name               0
# user_answer             11
# dtype: int64
#
# metrics:
# profession_name          0
# user_id                  0
# lp_avg_user              0
# statement_content        0
# value                    0
# question_title       64378
# user_answer          64378
# dtype: int64

# %% [markdown]
# Визуализируем пропуски

# %%
gaps_answers = (answers.isna().mean()*100).to_frame(name='gaps').query('gaps > 0').sort_values(by='gaps', ascending = False)

# визуализируем
barchart (12, 6, gaps_answers, 'gaps', gaps_answers.index, ['#80b1d3'], 
             'Доля пропусков по столбцам таблицы answers ', 'Доля, %', '',1,1,0,0,1,perc_frmt=1,set_xticks=1, edgecolor='black')

# %% [markdown]
# Столбец `statement_content`не заполенен, данные с пропусками сегментов можно удалить.

# %%
answers = answers.dropna(subset=['original_segment','current_segment', 'user_answer'])

# %%
gaps_metrics = (metrics.isna().mean()*100).to_frame(name='gaps').query('gaps > 0').sort_values(by='gaps', ascending = False)

# визуализируем
barchart (12, 6, gaps_metrics, 'gaps', gaps_metrics.index, ['#80b1d3'], 
             'Доля пропусков по столбцам таблицы metrics ', 'Доля, %', '',1,1,0,0,1,perc_frmt=1,set_xticks=1, edgecolor='black')

# %% [markdown]
# 80% строк с ответом на вопрос о рекомендации не заполенено, тк не все отвечали на этот вопрос.
# Оставим эти пропуски.

# %% [markdown]
# **Нулевые значения**

# %%
for table_name in spisok:
    table = eval(table_name)
    print('\n' + table_name + ':')
    zeros(table)
# Out:
# answers:
# user_id 0
# answer_date 0
# answer_id 0
# cohort 0
# course_name 0
# current_cohort 0
# current_segment 0
# lesson_name 0
# original_segment 0
# profession_name 0
# question_title 0
# question_type 0
# slide_position 36246
# statement_content 0
# topic_name 0
# user_answer 0
#
# metrics:
# profession_name 0
# user_id 0
# lp_avg_user 0
# statement_content 0
# value 13718
# question_title 0
# user_answer 234

# %% [markdown]
# Есть нули в столбце slide_position таблицы answers и в столбце user_answer таблицы metrics.
# В данном случае эти значения корректны.

# %% [markdown]
# ### Проверка дубликатов

# %% [markdown]
# **Таблица answers**

# %%
display(answers[answers.duplicated()])
# Out:
# Empty DataFrame
# Columns: [user_id, answer_date, answer_id, cohort, course_name, current_cohort, current_segment, lesson_name, original_segment, profession_name, question_title, question_type, slide_position, statement_content, topic_name, user_answer]
# Index: []

# %% [markdown]
# Проверим отвечал ли студент на один и тот же вопрос дважды

# %%
display(answers[answers[['user_id','question_title']].duplicated(keep=False)].head(10))
# Out:
#     user_id         answer_date                             answer_id  \
# 1      3157 2023-09-01 10:43:00  41ac1a75-1f3b-44bd-a2f2-346c3bdef7b3
# 4      3157 2023-09-01 10:43:00  41ac1a75-1f3b-44bd-a2f2-346c3bdef7b3
# 5      3157 2023-09-01 10:43:00  41ac1a75-1f3b-44bd-a2f2-346c3bdef7b3
# 6      3157 2023-09-01 10:43:00  41ac1a75-1f3b-44bd-a2f2-346c3bdef7b3
# 8      3157 2023-09-01 10:43:00  41ac1a75-1f3b-44bd-a2f2-346c3bdef7b3
# 9      3157 2023-09-01 10:43:00  41ac1a75-1f3b-44bd-a2f2-346c3bdef7b3
# 10     3157 2023-09-01 10:43:00  41ac1a75-1f3b-44bd-a2f2-346c3bdef7b3
# 14     5415 2023-08-03 13:40:00  9241a6bb-fa0a-4d56-944f-b32780d086f6
# 17     5415 2023-08-03 13:40:00  9241a6bb-fa0a-4d56-944f-b32780d086f6
# 18     5415 2023-08-03 13:40:00  9241a6bb-fa0a-4d56-944f-b32780d086f6
#
#              cohort      course_name   current_cohort current_segment  \
# 1   data_cohort_121  Трудоустройство  data_cohort_121             b2g
# 4   data_cohort_121  Трудоустройство  data_cohort_121             b2g
# 5   data_cohort_121  Трудоустройство  data_cohort_121             b2g
# 6   data_cohort_121  Трудоустройство  data_cohort_121             b2g
# 8   data_cohort_121  Трудоустройство  data_cohort_121             b2g
# 9   data_cohort_121  Трудоустройство  data_cohort_121             b2g
# 10  data_cohort_121  Трудоустройство  data_cohort_121             b2g
# 14  data_cohort_117  Трудоустройство  data_cohort_119             b2g
# 17  data_cohort_117  Трудоустройство  data_cohort_119             b2g
# 18  data_cohort_117  Трудоустройство  data_cohort_119             b2g
#
#       lesson_name original_segment profession_name  \
# 1   Цель обучения              b2g    data-analyst
# 4   Цель обучения              b2g    data-analyst
# 5   Цель обучения              b2g    data-analyst
# 6   Цель обучения              b2g    data-analyst
# 8   Цель обучения              b2g    data-analyst
# 9   Цель обучения              b2g    data-analyst
# 10  Цель обучения              b2g    data-analyst
# 14  Цель обучения              b2g    data-analyst
# 17  Цель обучения              b2g    data-analyst
# 18  Цель обучения              b2g    data-analyst
#
#                                                                                             question_title  \
# 1   Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.
# 4   Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.
# 5   Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.
# 6   Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.
# 8   Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.
# 9   Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.
# 10  Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.
# 14  Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.
# 17  Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.
# 18  Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.
#
#    question_type  slide_position  statement_content       topic_name  \
# 1       checkbox               0                NaN  Трудоустройство
# 4       checkbox               0                NaN  Трудоустройство
# 5       checkbox               0                NaN  Трудоустройство
# 6       checkbox               0                NaN  Трудоустройство
# 8       checkbox               0                NaN  Трудоустройство
# 9       checkbox               0                NaN  Трудоустройство
# 10      checkbox               0                NaN  Трудоустройство
# 14      checkbox               0                NaN  Трудоустройство
# 17      checkbox               0                NaN  Трудоустройство
# 18      checkbox               0                NaN  Трудоустройство
#
#                                user_answer
# 1       определение профессиональной сферы
# 4      персональная карьерная консультация
# 5                   устройство рынка труда
# 6   как и куда можно расти как специалисту
# 8                  сопроводительное письмо
# 9                                   резюме
# 10                решение тестовых заданий
# 14        оценка шансов на трудоустройство
# 17                  устройство рынка труда
# 18  как и куда можно расти как специалисту

# %% [markdown]
# На вопрос об опциях помощи допустимо несколько ответов

# %% [markdown]
# Проверим повторы на других вопросах

# %%
display(answers.loc[answers['question_title']!='Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.'\
        ,['user_id','question_title']][answers.loc[answers['question_title']!='Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.'\
        ,['user_id','question_title']].duplicated(keep=False)].head(10))
# Out:
#      user_id  \
# 734    90630
# 736    90630
# 737    90630
# 739    90630
# 740    90630
# 744    90630
# 745    90630
# 747    90630
# 749    90630
# 752    90630
#
#                                                                                                                                                                                                                                                           question_title
# 734  Бывает, что во время обучения меняется его цель. Например, изначально вы не планировали менять работу, но влюбились в профессию. Может, произошли жизненные изменения или вам сложно определить цель. Чтобы мы поняли, как помочь, отметьте подходящее утверждение:
# 736                                                                                                                                                                                                                       Планируете ли вы записаться на Карьерный Трек?
# 737                                                                   В зависимости от опыта работы вам может понадобиться разный вид консультаций и помощи от команды сопровождения и трудоустройства. Для нас очень важен честный ответ и понимание вашего бэкграунда.
# 739  Бывает, что во время обучения меняется его цель. Например, изначально вы не планировали менять работу, но влюбились в профессию. Может, произошли жизненные изменения или вам сложно определить цель. Чтобы мы поняли, как помочь, отметьте подходящее утверждение:
# 740                                                                                                                                                                                                                          Возможно вы нашли работу за время обучения?
# 744                                                                                                                                                                                  Тут вы можете оставить свой комментарий, если не нашли подходящего варианта ответа.
# 745                                                                                                                                                                                                                          Возможно вы нашли работу за время обучения?
# 747                                                                                                                                                                                  Тут вы можете оставить свой комментарий, если не нашли подходящего варианта ответа.
# 749                                                                   В зависимости от опыта работы вам может понадобиться разный вид консультаций и помощи от команды сопровождения и трудоустройства. Для нас очень важен честный ответ и понимание вашего бэкграунда.
# 752                                                                                                                                                                                                                       Планируете ли вы записаться на Карьерный Трек?

# %% [markdown]
# Есть дубликаты

# %%
answers[answers['user_id']==90630]
# Out:
#      user_id         answer_date                             answer_id  \
# 731    90630 2023-09-11 13:29:00  5d72ff48-aaca-4a66-83d2-79869e3f4ffa
# 732    90630 2023-09-11 13:29:00  5d72ff48-aaca-4a66-83d2-79869e3f4ffa
# 733    90630 2023-09-11 13:29:00  5d72ff48-aaca-4a66-83d2-79869e3f4ffa
# 734    90630 2023-09-11 13:29:00  d0ffb3e3-efba-4864-afb5-117fd7e2fc53
# 735    90630 2023-09-11 13:29:00  5d72ff48-aaca-4a66-83d2-79869e3f4ffa
# 736    90630 2023-08-01 17:20:00  778e7c65-6563-468f-a5a5-5478daf0df0d
# 737    90630 2023-08-01 17:20:00  1371c101-1732-461b-8e06-4e5223852c01
# 738    90630 2023-09-11 13:29:00  5d72ff48-aaca-4a66-83d2-79869e3f4ffa
# 739    90630 2023-08-01 17:20:00  778e7c65-6563-468f-a5a5-5478daf0df0d
# 740    90630 2023-08-01 17:21:00  5aac8a89-8ff6-4982-90b2-934ec6c999a5
# 741    90630 2023-08-01 17:21:00  b1c556ec-857c-48f8-81f2-f694a1590848
# 742    90630 2023-08-01 17:21:00  b1c556ec-857c-48f8-81f2-f694a1590848
# 743    90630 2023-09-11 13:29:00  5d72ff48-aaca-4a66-83d2-79869e3f4ffa
# 744    90630 2023-09-11 13:29:00  c8fdc78e-1c71-4a2d-93a9-a4765363034d
# 745    90630 2023-09-11 13:29:00  c8fdc78e-1c71-4a2d-93a9-a4765363034d
# 746    90630 2023-09-11 13:29:00  5d72ff48-aaca-4a66-83d2-79869e3f4ffa
# 747    90630 2023-08-01 17:21:00  5aac8a89-8ff6-4982-90b2-934ec6c999a5
# 748    90630 2023-08-01 17:21:00  b1c556ec-857c-48f8-81f2-f694a1590848
# 749    90630 2023-09-11 13:28:00  290ffc2b-3465-4bc9-bea9-6e26f2f71d40
# 750    90630 2023-08-01 17:21:00  b1c556ec-857c-48f8-81f2-f694a1590848
# 751    90630 2023-08-01 17:21:00  b1c556ec-857c-48f8-81f2-f694a1590848
# 752    90630 2023-09-11 13:29:00  d0ffb3e3-efba-4864-afb5-117fd7e2fc53
# 753    90630 2023-09-11 13:29:00  5d72ff48-aaca-4a66-83d2-79869e3f4ffa
#
#                             cohort      course_name  \
# 731  datavis-and-bi-tools_cohort_3  Трудоустройство
# 732  datavis-and-bi-tools_cohort_3  Трудоустройство
# 733  datavis-and-bi-tools_cohort_3  Трудоустройство
# 734  datavis-and-bi-tools_cohort_3  Трудоустройство
# 735  datavis-and-bi-tools_cohort_3  Трудоустройство
# 736    sql-data-analyst_cohort_147  Трудоустройство
# 737    sql-data-analyst_cohort_147  Трудоустройство
# 738  datavis-and-bi-tools_cohort_3  Трудоустройство
# 739    sql-data-analyst_cohort_147  Трудоустройство
# 740    sql-data-analyst_cohort_147  Трудоустройство
# 741    sql-data-analyst_cohort_147  Трудоустройство
# 742    sql-data-analyst_cohort_147  Трудоустройство
# 743  datavis-and-bi-tools_cohort_3  Трудоустройство
# 744  datavis-and-bi-tools_cohort_3  Трудоустройство
# 745  datavis-and-bi-tools_cohort_3  Трудоустройство
# 746  datavis-and-bi-tools_cohort_3  Трудоустройство
# 747    sql-data-analyst_cohort_147  Трудоустройство
# 748    sql-data-analyst_cohort_147  Трудоустройство
# 749  datavis-and-bi-tools_cohort_3  Трудоустройство
# 750    sql-data-analyst_cohort_147  Трудоустройство
# 751    sql-data-analyst_cohort_147  Трудоустройство
# 752  datavis-and-bi-tools_cohort_3  Трудоустройство
# 753  datavis-and-bi-tools_cohort_3  Трудоустройство
#
#                     current_cohort current_segment    lesson_name  \
# 731  datavis-and-bi-tools_cohort_3             b2c  Цель обучения
# 732  datavis-and-bi-tools_cohort_3             b2c  Цель обучения
# 733  datavis-and-bi-tools_cohort_3             b2c  Цель обучения
# 734  datavis-and-bi-tools_cohort_3             b2c  Цель обучения
# 735  datavis-and-bi-tools_cohort_3             b2c  Цель обучения
# 736    sql-data-analyst_cohort_147             b2c  Цель обучения
# 737    sql-data-analyst_cohort_147             b2c  Цель обучения
# 738  datavis-and-bi-tools_cohort_3             b2c  Цель обучения
# 739    sql-data-analyst_cohort_147             b2c  Цель обучения
# 740    sql-data-analyst_cohort_147             b2c  Цель обучения
# 741    sql-data-analyst_cohort_147             b2c  Цель обучения
# 742    sql-data-analyst_cohort_147             b2c  Цель обучения
# 743  datavis-and-bi-tools_cohort_3             b2c  Цель обучения
# 744  datavis-and-bi-tools_cohort_3             b2c  Цель обучения
# 745  datavis-and-bi-tools_cohort_3             b2c  Цель обучения
# 746  datavis-and-bi-tools_cohort_3             b2c  Цель обучения
# 747    sql-data-analyst_cohort_147             b2c  Цель обучения
# 748    sql-data-analyst_cohort_147             b2c  Цель обучения
# 749  datavis-and-bi-tools_cohort_3             b2c  Цель обучения
# 750    sql-data-analyst_cohort_147             b2c  Цель обучения
# 751    sql-data-analyst_cohort_147             b2c  Цель обучения
# 752  datavis-and-bi-tools_cohort_3             b2c  Цель обучения
# 753  datavis-and-bi-tools_cohort_3             b2c  Цель обучения
#
#     original_segment       profession_name  \
# 731              b2c  datavis-and-bi-tools
# 732              b2c  datavis-and-bi-tools
# 733              b2c  datavis-and-bi-tools
# 734              b2c  datavis-and-bi-tools
# 735              b2c  datavis-and-bi-tools
# 736              b2c      sql-data-analyst
# 737              b2c      sql-data-analyst
# 738              b2c  datavis-and-bi-tools
# 739              b2c      sql-data-analyst
# 740              b2c      sql-data-analyst
# 741              b2c      sql-data-analyst
# 742              b2c      sql-data-analyst
# 743              b2c  datavis-and-bi-tools
# 744              b2c  datavis-and-bi-tools
# 745              b2c  datavis-and-bi-tools
# 746              b2c  datavis-and-bi-tools
# 747              b2c      sql-data-analyst
# 748              b2c      sql-data-analyst
# 749              b2c  datavis-and-bi-tools
# 750              b2c      sql-data-analyst
# 751              b2c      sql-data-analyst
# 752              b2c  datavis-and-bi-tools
# 753              b2c  datavis-and-bi-tools
#
#                                                                                                                                                                                                                                                           question_title  \
# 731                                                                                                                                                               Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.
# 732                                                                                                                                                               Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.
# 733                                                                                                                                                               Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.
# 734  Бывает, что во время обучения меняется его цель. Например, изначально вы не планировали менять работу, но влюбились в профессию. Может, произошли жизненные изменения или вам сложно определить цель. Чтобы мы поняли, как помочь, отметьте подходящее утверждение:
# 735                                                                                                                                                               Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.
# 736                                                                                                                                                                                                                       Планируете ли вы записаться на Карьерный Трек?
# 737                                                                   В зависимости от опыта работы вам может понадобиться разный вид консультаций и помощи от команды сопровождения и трудоустройства. Для нас очень важен честный ответ и понимание вашего бэкграунда.
# 738                                                                                                                                                               Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.
# 739  Бывает, что во время обучения меняется его цель. Например, изначально вы не планировали менять работу, но влюбились в профессию. Может, произошли жизненные изменения или вам сложно определить цель. Чтобы мы поняли, как помочь, отметьте подходящее утверждение:
# 740                                                                                                                                                                                                                          Возможно вы нашли работу за время обучения?
# 741                                                                                                                                                               Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.
# 742                                                                                                                                                               Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.
# 743                                                                                                                                                               Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.
# 744                                                                                                                                                                                  Тут вы можете оставить свой комментарий, если не нашли подходящего варианта ответа.
# 745                                                                                                                                                                                                                          Возможно вы нашли работу за время обучения?
# 746                                                                                                                                                               Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.
# 747                                                                                                                                                                                  Тут вы можете оставить свой комментарий, если не нашли подходящего варианта ответа.
# 748                                                                                                                                                               Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.
# 749                                                                   В зависимости от опыта работы вам может понадобиться разный вид консультаций и помощи от команды сопровождения и трудоустройства. Для нас очень важен честный ответ и понимание вашего бэкграунда.
# 750                                                                                                                                                               Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.
# 751                                                                                                                                                               Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.
# 752                                                                                                                                                                                                                       Планируете ли вы записаться на Карьерный Трек?
# 753                                                                                                                                                               Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.
#
#     question_type  slide_position  statement_content       topic_name  \
# 731      checkbox               0                NaN  Трудоустройство
# 732      checkbox               0                NaN  Трудоустройство
# 733      checkbox               0                NaN  Трудоустройство
# 734         radio               0                NaN  Трудоустройство
# 735      checkbox               0                NaN  Трудоустройство
# 736         radio               1                NaN  Трудоустройство
# 737         radio               0                NaN  Трудоустройство
# 738      checkbox               0                NaN  Трудоустройство
# 739         radio               0                NaN  Трудоустройство
# 740         radio               0                NaN  Трудоустройство
# 741      checkbox               0                NaN  Трудоустройство
# 742      checkbox               0                NaN  Трудоустройство
# 743      checkbox               0                NaN  Трудоустройство
# 744          text               1                NaN  Трудоустройство
# 745         radio               0                NaN  Трудоустройство
# 746      checkbox               0                NaN  Трудоустройство
# 747          text               1                NaN  Трудоустройство
# 748      checkbox               0                NaN  Трудоустройство
# 749         radio               0                NaN  Трудоустройство
# 750      checkbox               0                NaN  Трудоустройство
# 751      checkbox               0                NaN  Трудоустройство
# 752         radio               1                NaN  Трудоустройство
# 753      checkbox               0                NaN  Трудоустройство
#
#                                                user_answer
# 731                              прохождение собеседований
# 732                                                 резюме
# 733                       оценка шансов на трудоустройство
# 734                                        Сменить работу.
# 735                                 устройство рынка труда
# 736                                      Да, уже записался
# 737  Нет опыта работы в IT и в направлении Анализа данных.
# 738                    персональная карьерная консультация
# 739                                        Сменить работу.
# 740                                                    Нет
# 741                 как и куда можно расти как специалисту
# 742                               решение тестовых заданий
# 743                                   оформление портфолио
# 744                                                      -
# 745                                                    Нет
# 746                               решение тестовых заданий
# 747                                                      -
# 748                              прохождение собеседований
# 749  Нет опыта работы в IT и в направлении Анализа данных.
# 750                    персональная карьерная консультация
# 751                       оценка шансов на трудоустройство
# 752                                      Да, уже записался
# 753                                сопроводительное письмо

# %% [markdown]
# Есть студенты, которые учились на разных курсах

# %% [markdown]
# Проверим дубликаты, исключив вопрос с чекбоксом и по сцепке ID, названия курса и вопроса

# %%
display(answers.loc[answers['question_title']!='Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.'\
        ,['user_id','profession_name', 'question_title']][answers.loc[answers['question_title']!='Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.'\
        ,['user_id','profession_name', 'question_title']].duplicated(keep=False)].head(20))
print('Доля дубликатов {:.2f}% строк датасета'.format(
      len(answers.loc[answers['question_title']!='Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.'\
        ,['user_id','profession_name', 'question_title']][answers.loc[answers['question_title']!='Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.'\
        ,['user_id','profession_name', 'question_title']].duplicated()])*100/len(answers)))
# Out:
#         user_id    profession_name  \
# 18040  12063477  data-analyst-plus
# 18043  12063477  data-analyst-plus
# 18046  12063477  data-analyst-plus
# 18050  12063477  data-analyst-plus
# 18053  12063477  data-analyst-plus
# 18055  12063477  data-analyst-plus
# 18056  12063477  data-analyst-plus
# 18057  12063477  data-analyst-plus
# 18058  12063477  data-analyst-plus
# 18064  12063477  data-analyst-plus
#
#                                                                                                                                                                                                                                                             question_title
# 18040  Бывает, что во время обучения меняется его цель. Например, изначально вы не планировали менять работу, но влюбились в профессию. Может, произошли жизненные изменения или вам сложно определить цель. Чтобы мы поняли, как помочь, отметьте подходящее утверждение:
# 18043                                                                   В зависимости от опыта работы вам может понадобиться разный вид консультаций и помощи от команды сопровождения и трудоустройства. Для нас очень важен честный ответ и понимание вашего бэкграунда.
# 18046                                                                   В зависимости от опыта работы вам может понадобиться разный вид консультаций и помощи от команды сопровождения и трудоустройства. Для нас очень важен честный ответ и понимание вашего бэкграунда.
# 18050                                                                                                                                                                                                                          Возможно вы нашли работу за время обучения?
# 18053                                                                                                                                                                                                                       Планируете ли вы записаться на Карьерный Трек?
# 18055                                                                                                                                                                                  Тут вы можете оставить свой комментарий, если не нашли подходящего варианта ответа.
# 18056                                                                                                                                                                                                                          Возможно вы нашли работу за время обучения?
# 18057                                                                                                                                                                                                                       Планируете ли вы записаться на Карьерный Трек?
# 18058  Бывает, что во время обучения меняется его цель. Например, изначально вы не планировали менять работу, но влюбились в профессию. Может, произошли жизненные изменения или вам сложно определить цель. Чтобы мы поняли, как помочь, отметьте подходящее утверждение:
# 18064                                                                                                                                                                                  Тут вы можете оставить свой комментарий, если не нашли подходящего варианта ответа.
# Доля дубликатов 0.01% строк датасета

# %% [markdown]
# Есть дубликаты, посмотрим пользователя отдельно

# %%
answers[answers['user_id']==12063477].sort_values(by='question_title')
# Out:
#         user_id         answer_date                             answer_id  \
# 18040  12063477 2023-08-22 17:46:00  4932642b-933e-46e8-8fe0-abaa04d1aa6d
# 18058  12063477 2023-09-03 09:17:00  fff2525c-a84a-46e5-9401-b6154260cffd
# 18043  12063477 2023-09-03 09:16:00  5a42f2ca-97f3-403f-972d-5246e26fa4aa
# 18046  12063477 2023-08-22 17:45:00  a6a29d9b-90ab-42e7-95bb-fdb715a15562
# 18056  12063477 2023-09-03 09:18:00  f7b94390-67b7-4cf3-8a46-813042de708b
# 18050  12063477 2023-08-22 17:56:00  988fb893-d183-4861-b092-20ecdda651cd
# 18039  12063477 2023-09-03 09:17:00  ec209d60-cf9c-4b65-9d11-69a08787d88e
# 18062  12063477 2023-08-22 17:47:00  f37ca347-8385-417d-b803-8386cb23f771
# 18061  12063477 2023-08-22 17:47:00  f37ca347-8385-417d-b803-8386cb23f771
# 18060  12063477 2023-09-03 09:17:00  ec209d60-cf9c-4b65-9d11-69a08787d88e
# 18059  12063477 2023-09-03 09:17:00  ec209d60-cf9c-4b65-9d11-69a08787d88e
# 18054  12063477 2023-09-03 09:17:00  ec209d60-cf9c-4b65-9d11-69a08787d88e
# 18052  12063477 2023-09-03 09:17:00  ec209d60-cf9c-4b65-9d11-69a08787d88e
# 18051  12063477 2023-08-22 17:47:00  f37ca347-8385-417d-b803-8386cb23f771
# 18049  12063477 2023-09-03 09:17:00  ec209d60-cf9c-4b65-9d11-69a08787d88e
# 18048  12063477 2023-08-22 17:47:00  f37ca347-8385-417d-b803-8386cb23f771
# 18047  12063477 2023-09-03 09:17:00  ec209d60-cf9c-4b65-9d11-69a08787d88e
# 18045  12063477 2023-09-03 09:17:00  ec209d60-cf9c-4b65-9d11-69a08787d88e
# 18044  12063477 2023-09-03 09:17:00  ec209d60-cf9c-4b65-9d11-69a08787d88e
# 18042  12063477 2023-08-22 17:47:00  f37ca347-8385-417d-b803-8386cb23f771
# 18041  12063477 2023-09-03 09:17:00  ec209d60-cf9c-4b65-9d11-69a08787d88e
# 18063  12063477 2023-09-03 09:17:00  ec209d60-cf9c-4b65-9d11-69a08787d88e
# 18053  12063477 2023-08-22 17:46:00  4932642b-933e-46e8-8fe0-abaa04d1aa6d
# 18057  12063477 2023-09-03 09:17:00  fff2525c-a84a-46e5-9401-b6154260cffd
# 18055  12063477 2023-09-03 09:18:00  f7b94390-67b7-4cf3-8a46-813042de708b
# 18064  12063477 2023-08-22 17:56:00  988fb893-d183-4861-b092-20ecdda651cd
#
#                             cohort      course_name  \
# 18040  data_analyst_plus_cohort_35  Трудоустройство
# 18058  data_analyst_plus_cohort_35  Трудоустройство
# 18043  data_analyst_plus_cohort_35  Трудоустройство
# 18046  data_analyst_plus_cohort_35  Трудоустройство
# 18056  data_analyst_plus_cohort_35  Трудоустройство
# 18050  data_analyst_plus_cohort_35  Трудоустройство
# 18039  data_analyst_plus_cohort_35  Трудоустройство
# 18062  data_analyst_plus_cohort_35  Трудоустройство
# 18061  data_analyst_plus_cohort_35  Трудоустройство
# 18060  data_analyst_plus_cohort_35  Трудоустройство
# 18059  data_analyst_plus_cohort_35  Трудоустройство
# 18054  data_analyst_plus_cohort_35  Трудоустройство
# 18052  data_analyst_plus_cohort_35  Трудоустройство
# 18051  data_analyst_plus_cohort_35  Трудоустройство
# 18049  data_analyst_plus_cohort_35  Трудоустройство
# 18048  data_analyst_plus_cohort_35  Трудоустройство
# 18047  data_analyst_plus_cohort_35  Трудоустройство
# 18045  data_analyst_plus_cohort_35  Трудоустройство
# 18044  data_analyst_plus_cohort_35  Трудоустройство
# 18042  data_analyst_plus_cohort_35  Трудоустройство
# 18041  data_analyst_plus_cohort_35  Трудоустройство
# 18063  data_analyst_plus_cohort_35  Трудоустройство
# 18053  data_analyst_plus_cohort_35  Трудоустройство
# 18057  data_analyst_plus_cohort_35  Трудоустройство
# 18055  data_analyst_plus_cohort_35  Трудоустройство
# 18064  data_analyst_plus_cohort_35  Трудоустройство
#
#                     current_cohort current_segment    lesson_name  \
# 18040  data_analyst_plus_cohort_35             b2g  Цель обучения
# 18058  data_analyst_plus_cohort_35             b2g  Цель обучения
# 18043  data_analyst_plus_cohort_35             b2g  Цель обучения
# 18046  data_analyst_plus_cohort_35             b2g  Цель обучения
# 18056  data_analyst_plus_cohort_35             b2g  Цель обучения
# 18050  data_analyst_plus_cohort_35             b2g  Цель обучения
# 18039  data_analyst_plus_cohort_35             b2g  Цель обучения
# 18062  data_analyst_plus_cohort_35             b2g  Цель обучения
# 18061  data_analyst_plus_cohort_35             b2g  Цель обучения
# 18060  data_analyst_plus_cohort_35             b2g  Цель обучения
# 18059  data_analyst_plus_cohort_35             b2g  Цель обучения
# 18054  data_analyst_plus_cohort_35             b2g  Цель обучения
# 18052  data_analyst_plus_cohort_35             b2g  Цель обучения
# 18051  data_analyst_plus_cohort_35             b2g  Цель обучения
# 18049  data_analyst_plus_cohort_35             b2g  Цель обучения
# 18048  data_analyst_plus_cohort_35             b2g  Цель обучения
# 18047  data_analyst_plus_cohort_35             b2g  Цель обучения
# 18045  data_analyst_plus_cohort_35             b2g  Цель обучения
# 18044  data_analyst_plus_cohort_35             b2g  Цель обучения
# 18042  data_analyst_plus_cohort_35             b2g  Цель обучения
# 18041  data_analyst_plus_cohort_35             b2g  Цель обучения
# 18063  data_analyst_plus_cohort_35             b2g  Цель обучения
# 18053  data_analyst_plus_cohort_35             b2g  Цель обучения
# 18057  data_analyst_plus_cohort_35             b2g  Цель обучения
# 18055  data_analyst_plus_cohort_35             b2g  Цель обучения
# 18064  data_analyst_plus_cohort_35             b2g  Цель обучения
#
#       original_segment    profession_name  \
# 18040              b2g  data-analyst-plus
# 18058              b2g  data-analyst-plus
# 18043              b2g  data-analyst-plus
# 18046              b2g  data-analyst-plus
# 18056              b2g  data-analyst-plus
# 18050              b2g  data-analyst-plus
# 18039              b2g  data-analyst-plus
# 18062              b2g  data-analyst-plus
# 18061              b2g  data-analyst-plus
# 18060              b2g  data-analyst-plus
# 18059              b2g  data-analyst-plus
# 18054              b2g  data-analyst-plus
# 18052              b2g  data-analyst-plus
# 18051              b2g  data-analyst-plus
# 18049              b2g  data-analyst-plus
# 18048              b2g  data-analyst-plus
# 18047              b2g  data-analyst-plus
# 18045              b2g  data-analyst-plus
# 18044              b2g  data-analyst-plus
# 18042              b2g  data-analyst-plus
# 18041              b2g  data-analyst-plus
# 18063              b2g  data-analyst-plus
# 18053              b2g  data-analyst-plus
# 18057              b2g  data-analyst-plus
# 18055              b2g  data-analyst-plus
# 18064              b2g  data-analyst-plus
#
#                                                                                                                                                                                                                                                             question_title  \
# 18040  Бывает, что во время обучения меняется его цель. Например, изначально вы не планировали менять работу, но влюбились в профессию. Может, произошли жизненные изменения или вам сложно определить цель. Чтобы мы поняли, как помочь, отметьте подходящее утверждение:
# 18058  Бывает, что во время обучения меняется его цель. Например, изначально вы не планировали менять работу, но влюбились в профессию. Может, произошли жизненные изменения или вам сложно определить цель. Чтобы мы поняли, как помочь, отметьте подходящее утверждение:
# 18043                                                                   В зависимости от опыта работы вам может понадобиться разный вид консультаций и помощи от команды сопровождения и трудоустройства. Для нас очень важен честный ответ и понимание вашего бэкграунда.
# 18046                                                                   В зависимости от опыта работы вам может понадобиться разный вид консультаций и помощи от команды сопровождения и трудоустройства. Для нас очень важен честный ответ и понимание вашего бэкграунда.
# 18056                                                                                                                                                                                                                          Возможно вы нашли работу за время обучения?
# 18050                                                                                                                                                                                                                          Возможно вы нашли работу за время обучения?
# 18039                                                                                                                                                               Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.
# 18062                                                                                                                                                               Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.
# 18061                                                                                                                                                               Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.
# 18060                                                                                                                                                               Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.
# 18059                                                                                                                                                               Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.
# 18054                                                                                                                                                               Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.
# 18052                                                                                                                                                               Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.
# 18051                                                                                                                                                               Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.
# 18049                                                                                                                                                               Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.
# 18048                                                                                                                                                               Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.
# 18047                                                                                                                                                               Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.
# 18045                                                                                                                                                               Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.
# 18044                                                                                                                                                               Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.
# 18042                                                                                                                                                               Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.
# 18041                                                                                                                                                               Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.
# 18063                                                                                                                                                               Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.
# 18053                                                                                                                                                                                                                       Планируете ли вы записаться на Карьерный Трек?
# 18057                                                                                                                                                                                                                       Планируете ли вы записаться на Карьерный Трек?
# 18055                                                                                                                                                                                  Тут вы можете оставить свой комментарий, если не нашли подходящего варианта ответа.
# 18064                                                                                                                                                                                  Тут вы можете оставить свой комментарий, если не нашли подходящего варианта ответа.
#
#       question_type  slide_position  statement_content       topic_name  \
# 18040         radio               0                NaN  Трудоустройство
# 18058         radio               0                NaN  Трудоустройство
# 18043         radio               0                NaN  Трудоустройство
# 18046         radio               0                NaN  Трудоустройство
# 18056         radio               0                NaN  Трудоустройство
# 18050         radio               0                NaN  Трудоустройство
# 18039      checkbox               0                NaN  Трудоустройство
# 18062      checkbox               0                NaN  Трудоустройство
# 18061      checkbox               0                NaN  Трудоустройство
# 18060      checkbox               0                NaN  Трудоустройство
# 18059      checkbox               0                NaN  Трудоустройство
# 18054      checkbox               0                NaN  Трудоустройство
# 18052      checkbox               0                NaN  Трудоустройство
# 18051      checkbox               0                NaN  Трудоустройство
# 18049      checkbox               0                NaN  Трудоустройство
# 18048      checkbox               0                NaN  Трудоустройство
# 18047      checkbox               0                NaN  Трудоустройство
# 18045      checkbox               0                NaN  Трудоустройство
# 18044      checkbox               0                NaN  Трудоустройство
# 18042      checkbox               0                NaN  Трудоустройство
# 18041      checkbox               0                NaN  Трудоустройство
# 18063      checkbox               0                NaN  Трудоустройство
# 18053         radio               1                NaN  Трудоустройство
# 18057         radio               1                NaN  Трудоустройство
# 18055          text               1                NaN  Трудоустройство
# 18064          text               1                NaN  Трудоустройство
#
#                                                                                                                                user_answer
# 18040                                                                                                                      Сменить работу.
# 18058                                                                                                                      Сменить работу.
# 18043                                                                                      От 1 года опыта работы в другом направлении IT.
# 18046                                                                                      От 1 года опыта работы в другом направлении IT.
# 18056                                                                                                                                  Нет
# 18050                                                                                                                                  Нет
# 18039                                                                                                               устройство рынка труда
# 18062                                                                                                                               резюме
# 18061                                                                                                              сопроводительное письмо
# 18060                                                                                               как и куда можно расти как специалисту
# 18059                                                                                                           как говорить про повышение
# 18054                                                                                                  определение стратегии поиска работы
# 18052                                                                                                                 оформление портфолио
# 18051                                                                                                            прохождение собеседований
# 18049                                                                                                            прохождение собеседований
# 18048                                                                                                             решение тестовых заданий
# 18047                                                                                                  персональная карьерная консультация
# 18045                                                                                                              сопроводительное письмо
# 18044                                                                                                                               резюме
# 18042                                                                                                                 оформление портфолио
# 18041                                                                                                     оценка шансов на трудоустройство
# 18063                                                                                                             решение тестовых заданий
# 18053                                                                                                Да, планирую записаться после диплома
# 18057                                                                                                                    Да, уже записался
# 18055                                                                                                  Я нашёл подходящие варианты ответа.
# 18064  Я работаю преподавателем IT-технологий, но так как оклад преподавателя сейчас составляет 6637 руб., то я хочу сменить место работы.

# %% [markdown]
# Есть пользователь, который смог ответить на один и тот же вопрос дважды в разное время.
# Возможно он проходил один и тот же курс дважды или это какая то техническая ошибка.
# Удалим этого пользователя, на общую картину один пользователь не повлияет.

# %%
answers = answers[answers['user_id']!=12063477]

# %% [markdown]
# Еще раз проверим дубликаты, исключив вопрос с чекбоксом и по сцепке ID, названия курса и вопроса

# %%
display(answers.loc[answers['question_title']!='Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.'\
        ,['user_id','profession_name', 'question_title']][answers.loc[answers['question_title']!='Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.'\
        ,['user_id','profession_name', 'question_title']].duplicated(keep=False)].head(20))
print('Доля дубликатов {:.2f}% строк датасета'.format(
      len(answers.loc[answers['question_title']!='Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.'\
        ,['user_id','profession_name', 'question_title']][answers.loc[answers['question_title']!='Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.'\
        ,['user_id','profession_name', 'question_title']].duplicated()])*100/len(answers)))
# Out:
# Empty DataFrame
# Columns: [user_id, profession_name, question_title]
# Index: []
# Доля дубликатов 0.00% строк датасета

# %% [markdown]
# Дубликатов не осталось

# %% [markdown]
# **Таблица metrics**

# %%
display(metrics[metrics.duplicated()])
# Out:
#        profession_name   user_id  lp_avg_user  \
# 6       data-scientist   7855703     0.611111
# 7       data-scientist   7855703     0.611111
# 8       data-scientist   7855703     0.611111
# 9       data-scientist   7855703     0.611111
# 10      data-scientist   7855703     0.611111
# ...                ...       ...          ...
# 79108   data-scientist   4701654     0.483333
# 79109   data-scientist   4701654     0.483333
# 79111  systems-analyst  14946989     0.845000
# 79112  systems-analyst  14946989     0.845000
# 79113  systems-analyst  14946989     0.845000
#
#                                                                                statement_content  \
# 6      Моя уверенность в своих знаниях значительно повысилась по сравнению с предыдущим спринтом
# 7      Моя уверенность в своих знаниях значительно повысилась по сравнению с предыдущим спринтом
# 8      Моя уверенность в своих знаниях значительно повысилась по сравнению с предыдущим спринтом
# 9      Моя уверенность в своих знаниях значительно повысилась по сравнению с предыдущим спринтом
# 10     Моя уверенность в своих знаниях значительно повысилась по сравнению с предыдущим спринтом
# ...                                                                                          ...
# 79108  Моя уверенность в своих знаниях значительно повысилась по сравнению с предыдущим спринтом
# 79109  Моя уверенность в своих знаниях значительно повысилась по сравнению с предыдущим спринтом
# 79111  Моя уверенность в своих знаниях значительно повысилась по сравнению с предыдущим спринтом
# 79112  Моя уверенность в своих знаниях значительно повысилась по сравнению с предыдущим спринтом
# 79113  Моя уверенность в своих знаниях значительно повысилась по сравнению с предыдущим спринтом
#
#        value question_title  user_answer
# 6          2            NaN          NaN
# 7          2            NaN          NaN
# 8          2            NaN          NaN
# 9          1            NaN          NaN
# 10         2            NaN          NaN
# ...      ...            ...          ...
# 79108      0            NaN          NaN
# 79109      0            NaN          NaN
# 79111      1            NaN          NaN
# 79112      1            NaN          NaN
# 79113      1            NaN          NaN
#
# [41817 rows x 7 columns]

# %%
print('Обнаружены дубликаты в количестве {:.1f}% строк датасета'.format(
len(metrics[metrics.duplicated()])*100/len(metrics)))
# Out:
# Обнаружены дубликаты в количестве 52.9% строк датасета

# %% [markdown]
# В таблице метрики есть дубликаты тк отсутствуют даты. Известно, что верхние строки более старые ответы. Не удаляем, используем последние данные

# %% [markdown]
# Проверим неявные дубликаты. Например, может быть путаница со строчными и прописными буквами.

# %%
# неявные дубликаты
for col in answers.columns:
    print('-' * 40 + col + '-' * 40 , end=' - ')
    display(answers[col].value_counts().to_frame())
# Out:
# ----------------------------------------user_id---------------------------------------- -
#           user_id
# 3178885        25
# 14357599       24
# 14874784       23
# 90630          23
# 14812917       18
# ...           ...
# 418740          1
# 14903633        1
# 13859025        1
# 12958053        1
# 15629755        1
#
# [3523 rows x 1 columns]
# ----------------------------------------answer_date---------------------------------------- -
#                      answer_date
# 2023-09-11 10:38:00           58
# 2023-08-28 10:17:00           35
# 2023-07-06 11:25:00           33
# 2023-08-28 13:39:00           33
# 2023-09-26 20:12:00           32
# ...                          ...
# 2023-09-02 16:58:00            1
# 2023-08-01 12:56:00            1
# 2023-08-28 19:46:00            1
# 2023-07-31 17:24:00            1
# 2023-07-25 17:59:00            1
#
# [7830 rows x 1 columns]
# ----------------------------------------answer_id---------------------------------------- -
#                                       answer_id
# 92847789-ab5d-43df-9382-4b697d987b4a         13
# 70772433-08ee-44f4-9b02-bdd7343444f9         13
# 6573ab37-2076-4bc4-b49a-f98e04976fd3         13
# 9e3614b0-efda-4b8e-9898-ea6006c081b9         13
# 39529a51-ee3e-4415-8211-e6bdcc999956         13
# ...                                         ...
# 16e713a0-cbb0-4db0-8af8-c6e346db0832          1
# c70be7d9-9b82-41b5-8e60-3c2e2e4866ae          1
# 9d7cd786-e30e-44d2-ac99-f6e18233917d          1
# ef4893f7-7437-4edb-b4a4-7bc99648c3b4          1
# 39f869b8-b64e-47dc-9de3-ead849c8fd3f          1
#
# [13989 rows x 1 columns]
# ----------------------------------------cohort---------------------------------------- -
#                              cohort
# data_cohort_119                3410
# ds_cohort_109                  2828
# ds_cohort_107                  2689
# data_cohort_117                2665
# data_cohort_121                2649
# ...                             ...
# sql-for-analyst_cohort_5          6
# sql-data-analyst_cohort_75        6
# sql-data-analyst_cohort_137       6
# sql-data-analyst_cohort_135       6
# ds_cohort_63                      1
#
# [159 rows x 1 columns]
# ----------------------------------------course_name---------------------------------------- -
#                  course_name
# Трудоустройство        43186
# ----------------------------------------current_cohort---------------------------------------- -
#                              current_cohort
# data_cohort_119                        3756
# ds_cohort_109                          2956
# data_cohort_121                        2945
# ds_cohort_107                          2700
# data_cohort_123                        2613
# ...                                     ...
# sql-data-analyst_cohort_135               6
# sql-for-analyst_cohort_5                  6
# sql-data-analyst_cohort_137               6
# sql-data-analyst_cohort_75                6
# ds_cohort_63                              1
#
# [162 rows x 1 columns]
# ----------------------------------------current_segment---------------------------------------- -
#      current_segment
# b2c            21561
# b2g            21392
# b2b              233
# ----------------------------------------lesson_name---------------------------------------- -
#                lesson_name
# Цель обучения        43186
# ----------------------------------------original_segment---------------------------------------- -
#      original_segment
# b2g             22385
# b2c             20568
# b2b               233
# ----------------------------------------profession_name---------------------------------------- -
#                        profession_name
# data-analyst                     18588
# data-scientist                   14840
# systems-analyst                   3661
# data-analyst-plus                 2320
# sql-data-analyst                  1587
# data-scientist-plus               1404
# datavis-and-bi-tools               239
# data-analyst-bootcamp              205
# data-engineer                      151
# math-for-da-ds                      96
# data-science-bootcamp               95
# ----------------------------------------question_title---------------------------------------- -
#                                                                                                                                                                                                                                                                      question_title
# Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.                                                                                                                                                                        25720
# В зависимости от опыта работы вам может понадобиться разный вид консультаций и помощи от команды сопровождения и трудоустройства. Для нас очень важен честный ответ и понимание вашего бэкграунда.                                                                             3531
# Бывает, что во время обучения меняется его цель. Например, изначально вы не планировали менять работу, но влюбились в профессию. Может, произошли жизненные изменения или вам сложно определить цель. Чтобы мы поняли, как помочь, отметьте подходящее утверждение:            3505
# Планируете ли вы записаться на Карьерный Трек?                                                                                                                                                                                                                                 3505
# Возможно вы нашли работу за время обучения?                                                                                                                                                                                                                                    3468
# Тут вы можете оставить свой комментарий, если не нашли подходящего варианта ответа.                                                                                                                                                                                            3457
# ----------------------------------------question_type---------------------------------------- -
#           question_type
# checkbox          25720
# radio             14009
# text               3457
# ----------------------------------------slide_position---------------------------------------- -
#    slide_position
# 0           36224
# 1            6962
# ----------------------------------------statement_content---------------------------------------- -
# Empty DataFrame
# Columns: [statement_content]
# Index: []
# ----------------------------------------topic_name---------------------------------------- -
#                  topic_name
# Трудоустройство       43186
# ----------------------------------------user_answer---------------------------------------- -
#                                                                                                                                          user_answer
# Нет                                                                                                                                             2732
# резюме                                                                                                                                          2677
# оформление портфолио                                                                                                                            2593
# прохождение собеседований                                                                                                                       2576
# решение тестовых заданий                                                                                                                        2427
# ...                                                                                                                                              ...
# Я не искал т.к. убеждён что еще не готов                                                                                                           1
# В данный момент работа и учеба не позволяют тратить время на поиск работы. Планирую этим заняться после или вовремя дипломного проекта.            1
# нашла все варианты                                                                                                                                 1
# Пока не уверен, что готов проходить собеседования, проверю свои силы после диплома                                                                 1
# Комментариев нет\n                                                                                                                                 1
#
# [1093 rows x 1 columns]

# %% [markdown]
# Проверим отдельно варианты ответов на вопросы, кроме открытого

# %%
answers[answers['question_title']!='Тут вы можете оставить свой комментарий, если не нашли подходящего варианта ответа.']\
['user_answer'].value_counts().to_frame().sort_index()
# Out:
#                                                         user_answer
# Более 3 лет опыта работы аналитиком.                             27
# Более 3 лет опыта работы в направлении Анализа данных.          154
# В активном поиске                                               568
# Да                                                              202
# Да, планирую записаться после диплома                          1929
# Да, уже записался                                              1285
# Менее 1 года опыта работы в другом направлении IT.              141
# Менее года опыта работы аналитиком.                              27
# Менее года опыта работы в направлении Анализа данных.           126
# Нет                                                            2698
# Нет определённой цели в обучении.                                61
# Нет опыта работы аналитиков и в IT.                              17
# Нет опыта работы аналитиком и в IT.                              83
# Нет опыта работы в IT и в направлении Анализа данных.          2240
# Нет, не планирую                                                291
# От 1 года опыта работы в другом направлении IT.                 492
# От 1 до 3 лет опыта работы аналитиком.                           48
# От 1 до 3 лет опыта работы направлении Анализа данных.          176
# Получить новые знания, чтобы повысить зарплату.                 346
# Получить новые навыки для общего развития.                      372
# Продвинуться по карьерной лестнице.                             215
# Развить свой бизнес.                                             40
# Сменить работу.                                                2299
# Структурировать уже полученные навыки и знания.                 172
# как говорить про повышение                                     1229
# как и куда можно расти как специалисту                         1724
# не думаю, что вы можете мне с чем-то помочь                     189
# определение профессиональной сферы                             1652
# определение стратегии поиска работы                            2303
# оформление портфолио                                           2593
# оценка шансов на трудоустройство                               2240
# персональная карьерная консультация                            1945
# прохождение собеседований                                      2576
# резюме                                                         2677
# решение тестовых заданий                                       2427
# сопроводительное письмо                                        2424
# устройство рынка труда                                         1741

# %%
answers = answers.replace({'user_answer': {'Получить новые навыки для общего развития.':'Для общего развития.',
                                            'Получить новые знания, чтобы повысить зарплату.':'Повышение зарплаты'}})

# %% [markdown]
# Есть неявные дубликаты 'Нет опыта работы аналитиков и в IT.'/ 'Нет опыта работы аналитиком и в IT.'
# Заменим

# %%
answers = answers.replace({'user_answer': {'Нет опыта работы аналитиков и в IT.':'Нет опыта работы аналитиком и в IT.'}})

# %% [markdown]
# Проверим формулировки нет опыта в анализе Данных и нет опыта работы аналитиком:

# %%
answers[answers['question_title']=='В зависимости от опыта работы вам может понадобиться разный вид консультаций и помощи от команды сопровождения и трудоустройства. Для нас очень важен честный ответ и понимание вашего бэкграунда.']\
                                    .pivot_table(index='profession_name',columns='user_answer', values='user_id',aggfunc='count')
# Out:
# user_answer            Более 3 лет опыта работы аналитиком.  \
# profession_name
# data-analyst                                            NaN
# data-analyst-bootcamp                                   NaN
# data-analyst-plus                                       NaN
# data-engineer                                           NaN
# data-science-bootcamp                                   NaN
# data-scientist                                          NaN
# data-scientist-plus                                     NaN
# datavis-and-bi-tools                                    NaN
# math-for-da-ds                                          NaN
# sql-data-analyst                                        NaN
# systems-analyst                                        27.0
#
# user_answer            Более 3 лет опыта работы в направлении Анализа данных.  \
# profession_name
# data-analyst                                                             44.0
# data-analyst-bootcamp                                                     NaN
# data-analyst-plus                                                         9.0
# data-engineer                                                             2.0
# data-science-bootcamp                                                     1.0
# data-scientist                                                           62.0
# data-scientist-plus                                                       5.0
# datavis-and-bi-tools                                                      5.0
# math-for-da-ds                                                            1.0
# sql-data-analyst                                                         20.0
# systems-analyst                                                           5.0
#
# user_answer            Менее 1 года опыта работы в другом направлении IT.  \
# profession_name
# data-analyst                                                         48.0
# data-analyst-bootcamp                                                 1.0
# data-analyst-plus                                                     3.0
# data-engineer                                                         1.0
# data-science-bootcamp                                                 1.0
# data-scientist                                                       54.0
# data-scientist-plus                                                   8.0
# datavis-and-bi-tools                                                  1.0
# math-for-da-ds                                                        NaN
# sql-data-analyst                                                      8.0
# systems-analyst                                                      16.0
#
# user_answer            Менее года опыта работы аналитиком.  \
# profession_name
# data-analyst                                           NaN
# data-analyst-bootcamp                                  NaN
# data-analyst-plus                                      NaN
# data-engineer                                          NaN
# data-science-bootcamp                                  NaN
# data-scientist                                         NaN
# data-scientist-plus                                    NaN
# datavis-and-bi-tools                                   NaN
# math-for-da-ds                                         NaN
# sql-data-analyst                                       NaN
# systems-analyst                                       27.0
#
# user_answer            Менее года опыта работы в направлении Анализа данных.  \
# profession_name
# data-analyst                                                            70.0
# data-analyst-bootcamp                                                    NaN
# data-analyst-plus                                                        4.0
# data-engineer                                                            1.0
# data-science-bootcamp                                                    1.0
# data-scientist                                                          34.0
# data-scientist-plus                                                      4.0
# datavis-and-bi-tools                                                     3.0
# math-for-da-ds                                                           NaN
# sql-data-analyst                                                         9.0
# systems-analyst                                                          NaN
#
# user_answer            Нет опыта работы аналитиком и в IT.  \
# profession_name
# data-analyst                                           NaN
# data-analyst-bootcamp                                  NaN
# data-analyst-plus                                      NaN
# data-engineer                                          NaN
# data-science-bootcamp                                  NaN
# data-scientist                                         NaN
# data-scientist-plus                                    NaN
# datavis-and-bi-tools                                   NaN
# math-for-da-ds                                         NaN
# sql-data-analyst                                       NaN
# systems-analyst                                      100.0
#
# user_answer            Нет опыта работы в IT и в направлении Анализа данных.  \
# profession_name
# data-analyst                                                          1117.0
# data-analyst-bootcamp                                                   13.0
# data-analyst-plus                                                      139.0
# data-engineer                                                            2.0
# data-science-bootcamp                                                    5.0
# data-scientist                                                         794.0
# data-scientist-plus                                                     70.0
# datavis-and-bi-tools                                                     9.0
# math-for-da-ds                                                           7.0
# sql-data-analyst                                                        72.0
# systems-analyst                                                         12.0
#
# user_answer            От 1 года опыта работы в другом направлении IT.  \
# profession_name
# data-analyst                                                     169.0
# data-analyst-bootcamp                                              2.0
# data-analyst-plus                                                 19.0
# data-engineer                                                      3.0
# data-science-bootcamp                                              NaN
# data-scientist                                                   175.0
# data-scientist-plus                                               20.0
# datavis-and-bi-tools                                               3.0
# math-for-da-ds                                                     2.0
# sql-data-analyst                                                  30.0
# systems-analyst                                                   69.0
#
# user_answer            От 1 до 3 лет опыта работы аналитиком.  \
# profession_name
# data-analyst                                              NaN
# data-analyst-bootcamp                                     NaN
# data-analyst-plus                                         NaN
# data-engineer                                             NaN
# data-science-bootcamp                                     NaN
# data-scientist                                            NaN
# data-scientist-plus                                       NaN
# datavis-and-bi-tools                                      NaN
# math-for-da-ds                                            NaN
# sql-data-analyst                                          NaN
# systems-analyst                                          48.0
#
# user_answer            От 1 до 3 лет опыта работы направлении Анализа данных.
# profession_name
# data-analyst                                                             70.0
# data-analyst-bootcamp                                                     1.0
# data-analyst-plus                                                        12.0
# data-engineer                                                             5.0
# data-science-bootcamp                                                     1.0
# data-scientist                                                           57.0
# data-scientist-plus                                                       3.0
# datavis-and-bi-tools                                                      6.0
# math-for-da-ds                                                            NaN
# sql-data-analyst                                                         15.0
# systems-analyst                                                           6.0

# %% [markdown]
# Формулировки *опыт работы аналитиком* присутствуют только по специальности Системный аналитика, поэтому заменим эту формулировку на *опыт в Анализе Данных*
# Также заменим формулировку *Менее года опыта работы в направлении Анализа данных.* на *Менее 1 года опыта работы в направлении Анализа данных.*

# %%
answers = answers.replace({'user_answer': {'Более 3 лет опыта работы аналитиком.':'Более 3 лет опыта работы в Анализе данных',
                                           'Более 3 лет опыта работы в направлении Анализа данных.':'Более 3 лет опыта работы в Анализе данных',
                                           'Менее года опыта работы в направлении Анализа данных.':'Менее 1 года опыта работы в Анализе данных',
                                           'Менее года опыта работы аналитиком.':'Менее 1 года опыта работы в Анализе данных',
                                           'Нет опыта работы в IT и в направлении Анализа данных.':'Нет опыта работы в IT и Анализе данных',                                           
                                           'Нет опыта работы аналитиком и в IT.':'Нет опыта работы в IT и Анализе данных',
                                           'От 1 до 3 лет опыта работы аналитиком.':'От 1 до 3 лет опыта работы в Анализе данных',
                                          'От 1 до 3 лет опыта работы направлении Анализа данных.':'От 1 до 3 лет опыта работы в Анализе данных',
                                          'Менее 1 года опыта работы в другом направлении IT.':'Менее 1 года опыта работы в другом направлении IT',
                                          'От 1 года опыта работы в другом направлении IT.':'От 1 года опыта работы в другом направлении IT'}})

# %% [markdown]
# Больше очевидных неявных дубликатов не обнаружено

# %%
# неявные дубликаты
for col in metrics.columns:
    print('-' * 40 + col + '-' * 40 , end=' - ')
    display(metrics[col].value_counts().to_frame())
# Out:
# ----------------------------------------profession_name---------------------------------------- -
#                        profession_name
# data-analyst                     32077
# data-scientist                   28573
# systems-analyst                   4600
# data-analyst-plus                 3029
# sql-data-analyst                  2712
# data-scientist-plus               2691
# data-engineer                     2434
# math-for-da-ds                    1813
# data-analyst-bootcamp              793
# data-science-bootcamp              395
# ----------------------------------------user_id---------------------------------------- -
#           user_id
# 13913671       64
# 2560890        60
# 15074343       60
# 14874784       55
# 3178885        54
# ...           ...
# 2434344         1
# 1623176         1
# 135710          1
# 114453          1
# 12020550        1
#
# [9797 rows x 1 columns]
# ----------------------------------------lp_avg_user---------------------------------------- -
#           lp_avg_user
# 0.930000         1956
# 0.810000         1348
# 0.820000         1271
# 0.790000         1197
# 0.890000         1189
# ...               ...
# 0.671818            1
# 0.615000            1
# 0.868750            1
# 0.852857            1
# 0.888333            1
#
# [3574 rows x 1 columns]
# ----------------------------------------statement_content---------------------------------------- -
#                                                                                            statement_content
# Моя уверенность в своих знаниях значительно повысилась по сравнению с предыдущим спринтом              79117
# ----------------------------------------value---------------------------------------- -
#     value
#  1  28424
#  2  28088
#  0  13718
# -1   6028
# -2   2859
# ----------------------------------------question_title---------------------------------------- -
#                                                                                                                                                           question_title
# Какова вероятность, что вы порекомендуете Практикум своим друзьям по шкале от 0 до 10, где 10 — обязательно порекомендую, 0 — не порекомендую ни за что?           14739
# ----------------------------------------user_answer---------------------------------------- -
#       user_answer
# 10.0         5502
# 8.0          2828
# 9.0          1993
# 7.0          1725
# 5.0           960
# 6.0           705
# 3.0           308
# 0.0           234
# 4.0           220
# 2.0           143
# 1.0           121

# %% [markdown]
# Очевидных неявных дубликатов не обнаружено

# %% [markdown]
# ### Добавление данных

# %% [markdown]
# Добавим столбец с сокращенным текстом вопроса 'question_title'

# %%
answers['question'] = answers['question_title']
answers = answers.replace({'question': {'Бывает, что во время обучения меняется его цель. Например, изначально вы не планировали менять работу, но влюбились в профессию. Может, произошли жизненные изменения или вам сложно определить цель. Чтобы мы поняли, как помочь, отметьте подходящее утверждение:':'Q1.Цель',
                                              'В зависимости от опыта работы вам может понадобиться разный вид консультаций и помощи от команды сопровождения и трудоустройства. Для нас очень важен честный ответ и понимание вашего бэкграунда.':'Q2.Бэкграунд',
                                              'Возможно вы нашли работу за время обучения?':'Q3.Нашли ли работу',
                                              'Для программы важно понять над чем вам нужно поработать. Не переживайте, вам будут доступны все опции.':'Q4.Опции',
                                              'Планируете ли вы записаться на Карьерный Трек?':'Q5.Карьерный Трек',
                                               'Тут вы можете оставить свой комментарий, если не нашли подходящего варианта ответа.':'Q6.Комментарии'}})

# %% [markdown]
# Создадим словарь для опыта

# %%
background = {
    'Нет опыта работы в IT и Анализе данных': 'beginners',
    'От 1 года опыта работы в другом направлении IT': 'others',
    'Более 3 лет опыта работы в Анализе данных': 'skilled',
    'От 1 до 3 лет опыта работы в Анализе данных': 'skilled',
    'Менее 1 года опыта работы в другом направлении IT': 'others',
    'Менее 1 года опыта работы в Анализе данных':'skilled'
}

# %% [markdown]
# ### Объединение таблиц

# %% [markdown]
# **Приведем таблицу answers к широкому виду**

# %%
answers_pt = answers.pivot_table(index=['user_id','cohort','current_segment','original_segment','profession_name'],
                           columns='question', values='user_answer', aggfunc='last').reset_index()
answers_pt.head(3)
# Out:
# question  user_id           cohort current_segment original_segment  \
# 0            3157  data_cohort_121             b2g              b2g
# 1            5415  data_cohort_117             b2g              b2g
# 2            8199  data_cohort_103             b2c              b2c
#
# question profession_name                              Q1.Цель  \
# 0           data-analyst  Продвинуться по карьерной лестнице.
# 1           data-analyst                      Сменить работу.
# 2           data-analyst                      Сменить работу.
#
# question                                    Q2.Бэкграунд Q3.Нашли ли работу  \
# 0                 Нет опыта работы в IT и Анализе данных                 Да
# 1         От 1 года опыта работы в другом направлении IT                Нет
# 2                 Нет опыта работы в IT и Анализе данных                Нет
#
# question                             Q4.Опции  \
# 0                    решение тестовых заданий
# 1         определение стратегии поиска работы
# 2                        оформление портфолио
#
# question                      Q5.Карьерный Трек Q6.Комментарии
# 0         Да, планирую записаться после диплома        Все ок)
# 1         Да, планирую записаться после диплома
# 2                             Да, уже записался              -

# %%
metrics_u = metrics.pivot_table(index=['user_id','profession_name'], values=[ 'value','user_answer','lp_avg_user'], aggfunc={'value': 'mean','user_answer': 'mean', 'lp_avg_user':'last'} )
metrics_u = metrics_u.sort_values(by='lp_avg_user', ascending=False).reset_index()
metrics_u.columns=['user_id','profession_name','learn_perf_avg','recom_avg','content_avg']
metrics_u['learn_perf_avg'] = round(metrics_u['learn_perf_avg'],3)
metrics_u['content_avg'] = round(metrics_u['content_avg'],3)
metrics_u.head()
# Out:
#     user_id        profession_name  learn_perf_avg  recom_avg  content_avg
# 0  14835089        systems-analyst            0.98        NaN        1.667
# 1  14590692        systems-analyst            0.98        NaN        0.000
# 2   2560890        systems-analyst            0.98        7.0        1.200
# 3    564151        systems-analyst            0.98        NaN        1.667
# 4   1567177  data-analyst-bootcamp            0.98        NaN        2.000

# %% [markdown]
# Соединим таблицы

# %%
data = answers_pt.merge( metrics_u,  how='inner', on=['user_id','profession_name'])
data.head(3)
# Out:
#    user_id           cohort current_segment original_segment profession_name  \
# 0     3157  data_cohort_121             b2g              b2g    data-analyst
# 1     5415  data_cohort_117             b2g              b2g    data-analyst
# 2     8199  data_cohort_103             b2c              b2c    data-analyst
#
#                                Q1.Цель  \
# 0  Продвинуться по карьерной лестнице.
# 1                      Сменить работу.
# 2                      Сменить работу.
#
#                                      Q2.Бэкграунд Q3.Нашли ли работу  \
# 0          Нет опыта работы в IT и Анализе данных                 Да
# 1  От 1 года опыта работы в другом направлении IT                Нет
# 2          Нет опыта работы в IT и Анализе данных                Нет
#
#                               Q4.Опции                      Q5.Карьерный Трек  \
# 0             решение тестовых заданий  Да, планирую записаться после диплома
# 1  определение стратегии поиска работы  Да, планирую записаться после диплома
# 2                 оформление портфолио                      Да, уже записался
#
#   Q6.Комментарии  learn_perf_avg  recom_avg  content_avg
# 0        Все ок)           0.652        NaN        1.250
# 1                          0.850        NaN        0.000
# 2              -           0.711        NaN       -0.167

# %% [markdown]
# ### Вывод
# Таблица **answers**:
#
# Все данные представлены по курсу `Трудойстройство`, тема урока: `Цель обучения`.
# Студентам было задано 6 вопросов: с 3 вариантами типа ответов: радиокнопка (возможен только 1 варивант ответа), чекбокс (возможны несколько вариантов ответа), текстовый ответ.
# В данных присутствовали дубликаты в количестве 0.01% датасета, были удалены.
# Присутствовали неявные  дубликаты в описании опыта работы - приведены к единому виду.
# Все пользователи так или и иначе учились на направлениях, связанных с наукой о данных. Всего 11 навравление, основные DA, DS, системные.
# Уникальных студентов: 3438чел.
# Все студенты разделены на 3 вида сегментов: b2c, b2g, b2b.
# В данных присуствовали пропуски в столбцах с видом сегмента, в количестве 1%, были удалены.
#
# Таблица **metrics**:
#
# Уникальных студентов: 9797чел.
# Студенты отвечали на 2 вопроса - об уверенности в собственных знаниях и о рекомендации Практикума.
# На второй вопрос ответили только 20% студентов(остальные пропустили, пропуски не были удалены, тк доля пропусков высока.
# Обнаружены дубликаты в количестве 53%, связано с тем, что в таблице отсутствуют даты выставления отметок.
# Аномальных значений в оценках не обнаружено.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Анализ студентов по специализации

# %%
prof_plot = answers_pt['profession_name'].value_counts().to_frame()

# %%
doughnut (15, 8, prof_plot.iloc[:6, 0].tolist() + [prof_plot['profession_name'].sum()-sum(prof_plot.iloc[:6, 0].tolist())]\
          , ['#23120B','#FDB827','#80b1d3','#23120B','#01ae76','#FDB827','#cccccc'], 0, 'Распределение студентов по специализации \n' \
          , ['DA','DS','System','DA plus','SQL DA','DS plus','other'], counterclock=False, color='w')

# %% [markdown]
# Большинство студентов обучаются на data-analyst и data-scientist - 84%. На третьем месте Системные аналитики - 9%

# %% [markdown]
# ### Анализ студентов по сегментам оплаты (B2B, B2C, B2G)

# %%
segments = data.groupby('original_segment').agg({'user_id':'count'}).join(data.groupby('current_segment').agg({'user_id':'count'}),\
                                                                          lsuffix='_orig', rsuffix='_cur')
segments = segments.reset_index().sort_values(by='user_id_orig', ascending=False)

# %%
segments
# Out:
#   original_segment  user_id_orig  user_id_cur
# 2              b2g          1680         1608
# 1              b2c          1445         1517
# 0              b2b            20           20

# %%
# визулизируем
ax = segments.plot(x='original_segment', kind='bar', stacked=False,figsize=(12, 6),\
                   color=['#80b1d3', '#FDB827'])
ax.legend(['начальный сегмент','текущий сегмент'])
sns.despine(top=True, right=True, left=True)
plt.title('Распределение пользователей по сегментам', fontsize=20) 
plt.xlabel('Сегменты')
plt.ylabel('Количество студентов');

# %% [markdown]
# Чуть более половины студентов оплачивают обучение с помощью государственных дотаций. На втором месте с небольшим отрывом те, кто учится за свой счет. К окончанию обучения незначительная часть людей (менее 1%) перешла с государственного на собственное финансирование, видимо не уложились в сроки обучения.
# Доля сегмента от бизнеса минимальна. Практикуму стоит потратить усилия для привлечения бизнес-клиентов и повышения интереса среди тех, кто готов учиться за свой счет.

# %% [markdown]
# ### Составление портретов студентов

# %% [markdown]
# #### Распределение ответов по пользователям в целом

# %%
user_answer = answers[answers['question']!='Q6.Комментарии']\
                .groupby(['question','user_answer']).size().reset_index(name='nunique')
user_answer['share,%'] = round(user_answer['nunique']*100/user_answer.groupby('question')['nunique'].transform('sum'),1)
user_answer = user_answer.sort_values(['question','share,%'],ascending = [True,False])

# %% [markdown]
# Визуализируем

# %%
user_answer = user_answer.sort_values(['question','share,%'],ascending = [True,True])
plt.figure(figsize = (15, 20))
title_set = 0
seria = 1
plt.subplots_adjust(hspace = 0.3)
title = ['Q1.Цель','Q2.Бэкграунд','Q3.Нашли ли работу','Q4.Опции','Q5.Карьерный Трек']
qu=['Q1.Цель','Q2.Бэкграунд','Q3.Нашли ли работу','Q4.Опции','Q5.Карьерный Трек']
for q in qu:
    ax = plt.subplot(5, 1, seria)
    user_answer[user_answer['question']==q][['user_answer','share,%']].set_index('user_answer')\
            .plot(kind='barh',ax = ax, color = '#80b1d3', legend=False)
    plt.xlabel("доля",size = 12)
    plt.ylabel("")
    # процентная шкала
    ax.xaxis.set_major_formatter(mtick.PercentFormatter())
    # подписи данных в процентах
    for p in ax.patches:
      ax.annotate(f"{p.get_width():.{0}f}%", (p.get_width(), p.get_y()+p.get_height()/2),
                    xytext=(5, 0), textcoords='offset points', ha="left", va="center", fontsize=10)
    plt.title(title[title_set], size =20)
    seria +=1
    title_set +=1
plt.tight_layout()
plt.show();

# %% [markdown]
# Основная цель студентов – сменить работу
# Большинство приходят учиться без опыта работы
# Записываются в карьерный трек во время обучения около 40%, а активно ищут работу я около 20%
# Самые востребованные опции карьерного центра: составление резюме, портфолио, навыки прохождения собеседования. Только 1% считает что им не нужна помощь.

# %% [markdown]
# #### Распределение ответов по направления обучения

# %%
# создаем словарь пар значений: название столбца - заголовок графика
q_col=data.iloc[:,5:10].columns.tolist()
q_title = ['Цели',
           'Опыт',
           'Нашли работу в процессе обучения',
           'Опции карьерной поддержки',
           'Участие в карьерном треке']
dict_q = dict(zip(q_col,q_title))

# %%
colors = {'Сменить работу.': '#80b1d3', 
          'Для общего развития.':'#fdc688', 
          'Повышение зарплаты': '#8dd3c7',
          'Продвинуться по карьерной лестнице.': '#fb8072',
          'Структурировать уже полученные навыки и знания.': '#ffffb3',
          'Нет определённой цели в обучении.': '#c3e589',
          'Развить свой бизнес. ': '#d9d9d9',
          'Нет опыта работы в IT и Анализе данных': '#80b1d3', 
          'От 1 года опыта работы в другом направлении IT':'#fdc688', 
          'От 1 до 3 лет опыта работы в Анализе данных': '#8dd3c7',
          'Более 3 лет опыта работы в Анализе данных': '#fb8072',
          'Менее 1 года опыта работы в Анализе данных': '#ffffb3',
          'Менее 1 года опыта работы в другом направлении IT': '#c3e589',
          'Нет': '#80b1d3', 
          'В активном поиске':'#fdc688', 
          'Да': '#8dd3c7',          
          'резюме': '#80b1d3', 
          'оформление портфолио':'#fdc688', 
          'прохождение собеседований': '#8dd3c7',
          'сопроводительное письмо': '#fb8072',
          'персональная карьерная консультация': '#ffffb3',
          'определение стратегии поиска работы': '#c3e589',
          'оценка шансов на трудоустройство': '#fccde5',
          'решение тестовых заданий': '#bebada',
          'не думаю, что вы можете мне с чем-то помочь': '#d9d9d9',
          'устройство рынка труда':'#bc80bd',
          'как и куда можно расти как специалисту':'#ccebc5',
          'определение профессиональной сферы':'#ffed6f',
          'как говорить про повышение':'#b9d4e7',
          'Да, планирую записаться после диплома': '#80b1d3', 
          'Да, уже записался':'#fdc688', 
          'Нет, не планирую': '#8dd3c7'
        }

# %%
answers_pt.iloc[:, 6].unique()
# Out:
# array(['Нет опыта работы в IT и Анализе данных',
#        'От 1 года опыта работы в другом направлении IT',
#        'Более 3 лет опыта работы в Анализе данных',
#        'От 1 до 3 лет опыта работы в Анализе данных',
#        'Менее 1 года опыта работы в другом направлении IT',
#        'Менее 1 года опыта работы в Анализе данных'], dtype=object)

# %%
viz_multiply('profession_name',dict_q,answers_pt,user_answer,answers, 4)
# Out:
# -------------------------Q1.ЦЕЛЬ ДЛЯ PROFESSION_NAME-------------------------
# -------------------------Q2.БЭКГРАУНД ДЛЯ PROFESSION_NAME-------------------------
# -------------------------Q3.НАШЛИ ЛИ РАБОТУ ДЛЯ PROFESSION_NAME-------------------------
# -------------------------Q4.ОПЦИИ ДЛЯ PROFESSION_NAME-------------------------
# -------------------------Q5.КАРЬЕРНЫЙ ТРЕК ДЛЯ PROFESSION_NAME-------------------------

# %% [markdown]
# `Аналитик данных`(43% всех студентов) и `Аналитик данных плюс`(5%) в основном выбирают люди, которые хотят сменить область деятельности, но не имеют возможности или потребности делать это в сжатые сроки. Также курс привлекателен для собственников бизнеса и уже работающих в этой или смежной областях людей. Большинство участников ставит перед собой цель смены работы, но есть и те, кто проходит курс для совершенствования на текущем месте.
# `Аналитик данных буткемп` (0.5%) выбирают люди, которые в данный момент не имеют постоянной работы и готовы потратить много сил и времени на обучение для трудоустройства.
# `Специалист по Data Science`(33%) и`Специалист по Data Science плюс` (3%)выбирают не только люди, которые хотят сменить область деятельности (хоть их больше половины), но и имеющие опыт с целью повысить квалификацию и получить новую работу или должность. Также обучение привлекательно для владельцев бизнеса. Ученики не имеют возможности или потребности получать знания и менять работу в срочном порядке.
# Почти половина людей, выбирающих `Data Science буткемп`(0.3%) уже имеет опыт в IT и ставит целью профессиональный рост и смену работы (видимо в рамках такого роста). Можно предположить что учащиеся должны быть хорошо мотивированы и иметь высокую успеваемость.
# `Системный аналитик`(9%) привлекателен для людей с опытом больше, чем для новичков. Значительная часть учащихся ставит целью повышение квалификации. Активно ищут работу всего 15%, что может указывать на то, что большинство имеет работу, но стремится сменить компанию или должность.
#  `SQL для работы с данными и аналитикой`(4.4%) выбирают люди, которые работают в аналитике, IT или смежных областях с целью получения новых знаний и опыта.
#
# `Визуализация данных и введение в BI инструменты`(0.8%) выбирают люди с опытом работы для повышения квалификации. Треть из них не нуждается в помощи с трудоустройством, мало кто активно ищет работу. Интересно, что это самый привлекательный курс для собственников бизнеса.
#
# Курс `Инженер данных` (0.4%)выбирает больше всего людей с опытом в аналитике и других областях IT, что закономерно поскольку он адресован людям с опытом определенными и знаниями. Активно ищут работу в два раза больше людей, чем участвуют в карьерном. Видимо у многих уже есть свой карьерный план.
#
# `Математика для анализа данных` (0.3%)- дополнительный курс для прокачки имеющихся навыков и знаний. Востребован как новичками, так и специалистами для повышения квалификации.
#
# Часть опросника имеет не совсем точные формулировки:
# **Цель: сменить работу**
# Должна быть разбита на 2 категории:  1- хотят сменить область деятельности (как правило новички), 2 – хотят сменить компанию-работодателя (учатся для повышения квалификации).
#
# **Нашли работу в процессе обучения: нет**
# Должна быть разбита на 2 категории: 1- ищу, но не нашел, 2- не ищу.
#
# **Нашли работу в процессе обучения: да**
# Должна быть разбита на 2 категории: 1- искал и нашел (желательно уточнить пригодилось ли обучение), 2- уже трудоустроен и менять не собираюсь.

# %% [markdown]
# #### Распределение ответов по сегментам

# %%
cnt_bgr = answers_pt[['profession_name','user_id','Q2.Бэкграунд']]\
            .pivot_table(index='profession_name',columns='Q2.Бэкграунд', values='user_id',aggfunc='count')

# %%
viz_multiply('original_segment',dict_q,answers_pt,user_answer,answers, 4)
# Out:
# -------------------------Q1.ЦЕЛЬ ДЛЯ ORIGINAL_SEGMENT-------------------------
# -------------------------Q2.БЭКГРАУНД ДЛЯ ORIGINAL_SEGMENT-------------------------
# -------------------------Q3.НАШЛИ ЛИ РАБОТУ ДЛЯ ORIGINAL_SEGMENT-------------------------
# -------------------------Q4.ОПЦИИ ДЛЯ ORIGINAL_SEGMENT-------------------------
# -------------------------Q5.КАРЬЕРНЫЙ ТРЕК ДЛЯ ORIGINAL_SEGMENT-------------------------

# %% [markdown]
# Государственными программами чаще всего пользуются новички (73%) с целью сменить работу (70%). Большая часть (95%) нуждается в помощи в трудоустройстве, треть (35%) записывается в карьерный трек во время обучения.  Имеют опыт в аналитике всего 10%, в других направлениях IT – 17%.
#
# За свой счет учится больше людей с опытом, чем по государственным программам: 20% работали в других областях IT, 21% работали в аналитике. Цель большинства – сменить работу (62%).  Больше всего пользуются карьерным треком во время обучения (39%).
#
# За счет бизнеса учатся люди, которые хотят продвинуться по карьерной лестнице или получить повышение зарплаты (46%), улучшить свои знания (20%). Некоторые указали смену работы (33%), 12% записались в карьерный трек, 4% активно ищут работу. Это говорит о том, что в этой группе не только повышающие квалификацию за счет компании. Возможно есть люди, которым удобнее оплачивать учебу от юридического лица (например собственного ИП).
# Также неожиданным кажется что в этой категории никто не выбрал развитие собственного бизнеса (в других категориях по 2%).  Нужно подробнее изучить эту группу для дальнейшего привлечения в Яндекс.

# %% [markdown]
# ### Зависимость целей от опыта

# %%
goals_bgr = answers_pt.pivot_table(index = 'Q1.Цель', columns='Q2.Бэкграунд',values='user_id',aggfunc='count')
#goals_bgr
goals_bgr_prct = goals_bgr.copy()
cols = goals_bgr_prct.columns.values
goals_bgr_prct[cols] = goals_bgr_prct[cols].div(goals_bgr_prct[cols].sum(axis=1), axis=0).multiply(100)
bgr_goals_prct = goals_bgr.T
cols = bgr_goals_prct.columns.values
bgr_goals_prct[cols] = bgr_goals_prct[cols].div(bgr_goals_prct[cols].sum(axis=1), axis=0)

# %%
# визуализируем
heatmapCr(bgr_goals_prct, 'Распределение цели в зависимости от опыта \n', '', '', annot=True,  fmt='.0%', vmin=-0.07,fontsize=20, figsize=(14, 10))

# %% [markdown]
# Люди без опыта в IT идут на обучение с основной целью – сменить работу (76%). Видимо имеется в виду смена области деятельности.
# Уже имеющие опыт в анализе данных (независимо от срока) стремятся получить новые знания чтобы повысить зарплату (21% - 27%). С опытом менее 1 года заинтересованы продвинуться по карьерной лестнице (17%) и сменить работу (42%), видимо подразумевая смену работодателя. С опытом более 1 года и более 3 лет  заинтересованы структурировать знания (17% и 15%) и возможно сменить работу (31% и 28%), также видимо подразумевая смену работодателя, а не область деятельности.
# Имеющие опыт в других направлениях IT учатся на аналитике чтобы сменить работу (49% - 55%). Они также указывают целями обучения повышение зарплаты (13%-16%), получение новых знаний (12%-16%), продвижение по карьерной лестнице (10% - 12%).
# Можно предположить что они изучили на собственном опыте разные специализации IT  и сделали осознанный выбор будущей профессии, решили дальше развиваться в аналитике.
#
# Судя по данному распределению помощь с карьерой необходима людям без опыта и нужна многим людям с опытом в других направлениях IT и в меньшей мере имеющим опыт в аналитике.

# %% [markdown]
# ### Зависимость опций карьерной поддержки от опыта

# %% [markdown]
# Добавим в таблицу answers сокращенный вариант опыта

# %%
answers['experience'] = answers['user_answer'].map(background)
#справочник user_id - опыт
experience = answers[~answers['experience'].isnull()][['user_id','experience']].drop_duplicates()
#добавим в таблицу answers
answers=answers.join(experience.set_index('user_id'), on='user_id',lsuffix='not')

# %%
help = answers[answers['question']=='Q4.Опции'].pivot_table(index='user_answer',columns='experience',values='user_id',aggfunc='count')

# %%
help_prct = help.copy().T
cols = help_prct .columns.values
help_prct[cols] = help_prct[cols].div(help_prct[cols].sum(axis=1), axis=0).multiply(100)
order = user_answer[user_answer['question']=='Q4.Опции']['user_answer'][::-1]
help_prct = help_prct.reindex(columns=order)
help_prct = help_prct.sort_values(by=help_prct.columns[0])
#визуализируем
barh (help_prct, 12, 8,colors, 'Опции помощи \n', 'Доли', '', 1, 1, 1, 1, 0,perc_frmt= 1, legend=1, legend_text=order)

# %% [markdown]
# При составлении портрета пользователей мы рассмотрели распределение опций помощи карьерного центра по направлениям обучения и не нашли зависимостей. Было предположение что эти опции могут зависеть от опыта работы.
# Запросы отличаются мало,все опции востребованы примерно одинаково.  Самыми важными для всех являются навыки самопрезентации: составление резюме, оформление портфолио,  прохождение собеседований.
# Одинаково важным все считают изучение рынка труда и своей ниши в нем: определение стратегии поиска, оценка шансов, персональная консультация.
# Определение профессиональной сферы больше волнует новичков, в меньшей степени опытных специалистов.
# Как говорить про повышение интересует специалистов больше, чем новичков.
# Можно сделать вывод, что все опции помощи карьерного центра одинаково важны всем обучающимся, независимо от выбранной специальности и опыта работы.

# %% [markdown]
# ### Анализ пользователей по уровням  learning performance и уверенности в знаниях content

# %% [markdown]
# #### Анализ пользователей по learning performance

# %% [markdown]
# Посмотрим распределение метрик по данным полученным из таблицы метрики, тк там содержится больше студентов и картина будет более полной

# %%
median = round(metrics_u['learn_perf_avg'].median(), 2)
plt.figure(figsize=(14, 7))
ax = plt.subplot(1, 1, 1)
hist = plt.hist(metrics_u['learn_perf_avg'], bins=100, color='#FDB827')
plt.title('Распределение пользователей по среднему learning performance \n ', fontsize=20)
plt.xlabel('Оценка эффективности пользователей')
plt.ylabel('Количество пользователей')
plt.xticks(np.arange(0,1.01, 0.1))
sns.despine(top=True, right=True, left=True, bottom=True) 
ax.axvline(median, linewidth=2, color='darkgreen', linestyle='--', label = 'Медиана = {:,.2f}'.format(median))
plt.legend(fontsize="12")
plt.show;

# %% [markdown]
# Эффективность большинства студентов 0,7-0,8
# Выделяется выброс на уровне между 0,9 - 1
# Посмотри что это за оценки:

# %%
metrics_u[metrics_u['learn_perf_avg']>0.9]['profession_name'].value_counts()
# Out:
# systems-analyst          380
# sql-data-analyst         325
# data-scientist            97
# data-analyst              61
# data-engineer             52
# data-scientist-plus       26
# data-science-bootcamp     11
# data-analyst-plus         10
# data-analyst-bootcamp      7
# math-for-da-ds             3
# Name: profession_name, dtype: int64

# %% [markdown]
# Такие высоки оценки демонстрирую только systems-analyst и sql-data-analyst направления
# Стоит проверить почему только данные направления оценены так высоко. Возможо стоит посмотреть данные за другой период

# %% [markdown]
# Для целей нашего исследования, предварительно разделим пользователей на две группы библиотекой jenkspy

# %%
lp_breaks = jenkspy.jenks_breaks(metrics_u['learn_perf_avg'], 2)
lp_breaks
# Out:
# [0.14, 0.713, 0.98]

# %% [markdown]
# Граница получилась чуть ниже медианы, что подходит нам тк медиана немного завышена из-за высоких оценок системных аналитиков и sql аналитиков

# %% [markdown]
# #### Анализ пользователей по уверенности в знаниях

# %%
median = round(metrics_u['content_avg'].median(), 2)
plt.figure(figsize=(14, 7))
ax = plt.subplot(1, 1, 1)
hist = plt.hist(metrics_u['content_avg'], bins=41, color='#FDB827')
plt.title('Распределение пользователей по среднему уровню уверенности \n ', fontsize=20)
plt.xlabel('Оценка эффективности пользователей')
plt.ylabel('Количество пользователей')
sns.despine(top=True, right=True, left=True, bottom=True) 
ax.axvline(median, linewidth=2, color='darkgreen', linestyle='--', label = 'Медиана = {:,.2f}'.format(median))
plt.legend(fontsize="12")
plt.show;

# %% [markdown]
# Большинство студентов оценивает свою уверенность в знаниях на 1-2 пункта по шкале от -2 до 2

# %% [markdown]
# Для целей нашего исследования, предварительно разделим пользователей на две группы - по значению больше или равно 1, как скорее уверенных в себе пользователей, и менее 1, как менее уверенных в себе пользователей

# %%
с_breaks = [metrics_u['content_avg'].min(), metrics_u['content_avg'].median()-0.01, metrics_u['content_avg'].max()]
с_breaks
# Out:
# [-2.0, 0.99, 2.0]

# %% [markdown]
# #### Корреляция между learning performance и уверенностью студента в знаниях

# %% [markdown]
# Проверим корреляцию между эффективностью и уверенностью в знаниях

# %%
metrics_u.plot(x='learn_perf_avg',y='content_avg', kind='scatter', color='#FDB827',figsize = (10,7))
plt.title('Корреляция между learning performance и уверенностью студента в знания \n ', fontsize=20)
plt.xlabel('Эффективность')
plt.ylabel('Уверенность в знаниях')                                                                               
print("Коэффициент Пирсона", metrics_u['learn_perf_avg'].corr(metrics_u['content_avg']));
# Out:
# Коэффициент Пирсона 0.07559779569781103

# %% [markdown]
# Корреляции нет.
# Проверим есть ли корреляция внутри направлений профессий

# %%
name_l = []
corr_l = []
for uniq in data['profession_name'].unique():
  name_l.append(uniq)
  data_segment = metrics[metrics['profession_name'] ==uniq]
  g = data_segment['value'].corr(data_segment['lp_avg_user'])
  corr_l.append(g)
df_corr = pd.DataFrame({
    'Профессии' : name_l,
    'Корреляция' : corr_l
})
df_corr.sort_values('Корреляция',ascending=False).style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_f5773_row0_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_f5773_row1_col1{
#             background-color:  #da5a49;
#             color:  #000000;
#         }#T_f5773_row2_col1{
#             background-color:  #e0654f;
#             color:  #000000;
#         }#T_f5773_row3_col1{
#             background-color:  #f7ba9f;
#             color:  #000000;
#         }#T_f5773_row4_col1{
#             background-color:  #e3d9d3;
#             color:  #000000;
#         }#T_f5773_row5_col1{
#             background-color:  #dadce0;
#             color:  #000000;
#         }#T_f5773_row6_col1{
#             background-color:  #d9dce1;
#             color:  #000000;
#         }#T_f5773_row7_col1{
#             background-color:  #6282ea;
#             color:  #000000;
#         }#T_f5773_row8_col1{
#             background-color:  #4f69d9;
#             color:  #000000;
#         }#T_f5773_row9_col1{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }</style><table id="T_f5773_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Профессии</th>        <th class="col_heading level0 col1" >Корреляция</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f5773_level0_row0" class="row_heading level0 row0" >9</th>
#                         <td id="T_f5773_row0_col0" class="data row0 col0" >data-science-bootcamp</td>
#                         <td id="T_f5773_row0_col1" class="data row0 col1" >0.061533</td>
#             </tr>
#             <tr>
#                         <th id="T_f5773_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f5773_row1_col0" class="data row1 col0" >data-scientist</td>
#                         <td id="T_f5773_row1_col1" class="data row1 col1" >0.051590</td>
#             </tr>
#             <tr>
#                         <th id="T_f5773_level0_row2" class="row_heading level0 row2" >7</th>
#                         <td id="T_f5773_row2_col0" class="data row2 col0" >math-for-da-ds</td>
#                         <td id="T_f5773_row2_col1" class="data row2 col1" >0.049771</td>
#             </tr>
#             <tr>
#                         <th id="T_f5773_level0_row3" class="row_heading level0 row3" >2</th>
#                         <td id="T_f5773_row3_col0" class="data row3 col0" >data-analyst-plus</td>
#                         <td id="T_f5773_row3_col1" class="data row3 col1" >0.032173</td>
#             </tr>
#             <tr>
#                         <th id="T_f5773_level0_row4" class="row_heading level0 row4" >0</th>
#                         <td id="T_f5773_row4_col0" class="data row4 col0" >data-analyst</td>
#                         <td id="T_f5773_row4_col1" class="data row4 col1" >0.020558</td>
#             </tr>
#             <tr>
#                         <th id="T_f5773_level0_row5" class="row_heading level0 row5" >3</th>
#                         <td id="T_f5773_row5_col0" class="data row5 col0" >systems-analyst</td>
#                         <td id="T_f5773_row5_col1" class="data row5 col1" >0.017435</td>
#             </tr>
#             <tr>
#                         <th id="T_f5773_level0_row6" class="row_heading level0 row6" >4</th>
#                         <td id="T_f5773_row6_col0" class="data row6 col0" >data-scientist-plus</td>
#                         <td id="T_f5773_row6_col1" class="data row6 col1" >0.017168</td>
#             </tr>
#             <tr>
#                         <th id="T_f5773_level0_row7" class="row_heading level0 row7" >5</th>
#                         <td id="T_f5773_row7_col0" class="data row7 col0" >sql-data-analyst</td>
#                         <td id="T_f5773_row7_col1" class="data row7 col1" >-0.013740</td>
#             </tr>
#             <tr>
#                         <th id="T_f5773_level0_row8" class="row_heading level0 row8" >6</th>
#                         <td id="T_f5773_row8_col0" class="data row8 col0" >data-engineer</td>
#                         <td id="T_f5773_row8_col1" class="data row8 col1" >-0.018792</td>
#             </tr>
#             <tr>
#                         <th id="T_f5773_level0_row9" class="row_heading level0 row9" >8</th>
#                         <td id="T_f5773_row9_col0" class="data row9 col0" >data-analyst-bootcamp</td>
#                         <td id="T_f5773_row9_col1" class="data row9 col1" >-0.024702</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# По направлениям обучения корреляции также нет

# %% [markdown]
# ### Зависимость уровня знаний и уверенности студента от опыта и целей

# %% [markdown]
# Посмотрим как распределяются показатели эффективности и уверенности в знаниях по ответам на заданные студентам вопросы:

# %%
data_melt = data.melt(id_vars=['user_id', 'profession_name','learn_perf_avg','content_avg'], 
                                               value_vars=['Q1.Цель','Q2.Бэкграунд','Q3.Нашли ли работу','Q5.Карьерный Трек'])
data_melt=data_melt.rename(columns={'variable':'Q','value':'A'})
scores_avg = data_melt.groupby(['Q','A']).agg({'learn_perf_avg':'mean','content_avg':'mean'}).reset_index()

# %%
#визуализируем
 
scores_avg.columns = scores_avg.columns.map(''.join)
fig, ax = plt.subplots(nrows= 2, ncols= 2, figsize=(18, 18))
place = 1
for q in scores_avg['Q'].unique():
    plt.subplot(2,2,place)
    score_q = scores_avg[scores_avg['Q'] == q]
    tidy =score_q.drop('Q', axis=1)
    tidy = tidy.melt(id_vars='A').rename(columns=str.title).sort_values('Value', ascending=False)
    sns.barplot(x='A', hue='Variable', y='Value', data=tidy, palette='muted')
    plt.xticks(rotation=90)
    plt.xlabel('Ответы')
    plt.ylabel('Числовая оценка PL и content')  
    plt.title(q)
    plt.tight_layout()
    plt.legend(fontsize="10")
    plt.ylim(bottom=0.2)
    place +=1

plt.show()

# %% [markdown]
#
# У тех, кто пришел **структурировать знания** – самая **высокая эффективность** и самый **высокий уровень уверенности** в знаниях, самые низкие показатели у студентов без определенной цели в обучении
# У студентов с опытом от **1 до 3** лет самый **высокий уровень уверенности** в знаниях, но **самые эффективные** с опытом **более 3 лет**, а уверенности у них наоборот **минимальная**
# У те, кто **нашел работу** самый **высокий уровень эффективности**, а самые уверенные еще в активном поиске
# Самые **уверенные** студенты уже записались на карьерный трек

# %% [markdown]
# ## Формирование сегментов в зависимости от уровня знаний и уверенности студента в себе

# %% [markdown]
# Добавим по установленным ранее границам для уровней learning perfomance и уверенности content столбцы с рейтингами

# %%
# рейтинги по установленным границам каждого параметра
data['lp_score'] = pd.cut(data['learn_perf_avg'], bins=lp_breaks, labels=[2, 1], include_lowest=True)
data['content_score'] = pd.cut(data['content_avg'], bins=с_breaks, labels=[2, 1], include_lowest=True)
# общий рейтинг
data['pc_score'] = data['lp_score'].astype(str) + data['content_score'].astype(str)

# %% [markdown]
# Присвоим названия нашим сегментам

# %%
conditions = [
    (data['pc_score']=='11'),
    (data['pc_score']=='12'),
    (data['pc_score']=='21'),
    (data['pc_score']=='22')
    ]
values = ['Cluster_1','Cluster_2','Cluster_3 ','Cluster_4 ']
data['cluster'] = np.select(conditions, values)

# %% [markdown]
# **Визуализируем количество студентов в каждом сегменте**

# %%
# визуализируем
data_plot = data['cluster'].value_counts().to_frame()
barchart (14, 7, data_plot, data_plot.index, 'cluster', ['#FDB827'], 
             'Распределение сегментов по количеству студентов \n', 'Сегменты', 'Количество учащихся', 1, 1, 1, 0, 
                0, horizont=0, set_xticks=1)

# %%
mean_metrics = data.pivot_table(index='pc_score', values=['learn_perf_avg','content_avg'], aggfunc='mean').round(2)

# %% [markdown]
# **Описание сегментов**

# %% [markdown]
# |Сегмент    | Расшифровка  | learn_perf_avg|content_avg |
# |----------|----------|------------------|---------------|
# | Cluster_1 - 11    |  Эффективные, уверенные в себе   | 0,83|1,51|
# | Cluster_2 - 12    |  Эффективные, неуверенные в себе   | 0,81|0,16|
# | Cluster_3 - 21    |  Неэффективные, уверенные в себе    |0,62|1,49|
# | Cluster_4 - 22    | Неэффективные, неуверенные в себе    |0,62|0,05|

# %% [markdown]
# Самая крупная категория ~ 30% демонстрирует высокую эффективность и уверенность в себе
# Самая малочисленная ~ 20% - эффективные, но неуверенные в себе студенты

# %% [markdown]
# ### Проверка статистических гипотез

# %% [markdown]
# **Сравним уровень learn_perfomance между нашими когортами студентов**
#
#
# Для выбора теста проверим данные на нормальность по Критерию Шапиро-Уилка.

# %%
alpha = 0.05  # критический уровень статистической значимости

results = st.shapiro(data['learn_perf_avg'])
p_value = results[1]  #- p-value

print('p-значение: ', p_value)

if p_value < alpha:
    print('Отвергаем нулевую гипотезу: распределение не нормально')
else:
    print('Не получилось отвергнуть нулевую гипотезу, всё нормально')
# Out:
# p-значение:  2.1973938293951e-11
# Отвергаем нулевую гипотезу: распределение не нормально

# %% [markdown]
# Распределение ненормально, сравнение величин будем проводить тестом Уилкоксона-Манна-Уитни
#
# Так как в нашем тесте более, чем две группы и несколько сравнений, увеличивается вероятность получить ошибку первого рода(найти разницу там где ее нет).
# Необходимо скорректировать уровень значимости.
# Воспользуемся методом Холма.

# %% [markdown]
# Сравнение всех групп по показателю `learn_perf_avg`

# %%
test_p = []
test_name = []
test_mwu_update('learn_perf_avg', test_p,test_name)
# Out:
# Гипотезы.
#
# H0 - Между gr_11 и gr_12 статистически значимого отличия нет.
# H1 - Между gr_11 и gr_12 есть статистически значимая разница.
#
#
# alpha: 0.050
# Среднее первой группы gr_11 : 0.820
# Среднее второй группы gr_12 : 0.800
# results.pvalue: 0.00000
# ------------------------------------------------------------
# Гипотезы.
#
# H0 - Между gr_11 и gr_21 статистически значимого отличия нет.
# H1 - Между gr_11 и gr_21 есть статистически значимая разница.
#
#
# alpha: 0.050
# Среднее первой группы gr_11 : 0.820
# Среднее второй группы gr_21 : 0.608
# results.pvalue: 0.00000
# ------------------------------------------------------------
# Гипотезы.
#
# H0 - Между gr_11 и gr_22 статистически значимого отличия нет.
# H1 - Между gr_11 и gr_22 есть статистически значимая разница.
#
#
# alpha: 0.050
# Среднее первой группы gr_11 : 0.820
# Среднее второй группы gr_22 : 0.608
# results.pvalue: 0.00000
# ------------------------------------------------------------
# Гипотезы.
#
# H0 - Между gr_12 и gr_21 статистически значимого отличия нет.
# H1 - Между gr_12 и gr_21 есть статистически значимая разница.
#
#
# alpha: 0.050
# Среднее первой группы gr_12 : 0.800
# Среднее второй группы gr_21 : 0.608
# results.pvalue: 0.00000
# ------------------------------------------------------------
# Гипотезы.
#
# H0 - Между gr_12 и gr_22 статистически значимого отличия нет.
# H1 - Между gr_12 и gr_22 есть статистически значимая разница.
#
#
# alpha: 0.050
# Среднее первой группы gr_12 : 0.800
# Среднее второй группы gr_22 : 0.608
# results.pvalue: 0.00000
# ------------------------------------------------------------
# Гипотезы.
#
# H0 - Между gr_21 и gr_22 статистически значимого отличия нет.
# H1 - Между gr_21 и gr_22 есть статистически значимая разница.
#
#
# alpha: 0.050
# Среднее первой группы gr_21 : 0.608
# Среднее второй группы gr_22 : 0.608
# results.pvalue: 0.99700
# ------------------------------------------------------------

# %%
# названия сравнений-гипотез
test_name
# Out:
# ['gr_11_gr_12',
#  'gr_11_gr_21',
#  'gr_11_gr_22',
#  'gr_12_gr_21',
#  'gr_12_gr_22',
#  'gr_21_gr_22']

# %%
# последовательность p-value
test_p
# Out:
# [1.2907684033623154e-07,
#  5.402297933920234e-285,
#  9.225053254606626e-275,
#  2.4652615513446546e-235,
#  2.4838839208531582e-228,
#  0.9970031717269445]

# %%
# сгененируем последовательность скорректированных yровней значимости
alpha_cor = []
for m in [i for i in range(len(test_p), 0, -1)]:
    alpha_cor.append(0.05/m)
display(alpha_cor)
# Out:
# [0.008333333333333333, 0.01, 0.0125, 0.016666666666666666, 0.025, 0.05]

# %%
#создадим датафрейм из p_value и добавим номер гипотезы
number_of_hyp = np.arange(1, len(test_p)+1).tolist()
check_hyp = pd.DataFrame({'hyp_names':test_name,  'p_value': test_p},index=number_of_hyp)
#отсортируем от самого низкого значения p_value
check_hyp.sort_values(by = 'p_value',inplace=True)
#добавим alpha
check_hyp['alpha'] = alpha_cor
#добавим столбец с проверкой, если p_value больше alpha, то Истина
check_hyp['p_value_more_alpha'] = np.where(check_hyp['p_value']>= check_hyp['alpha'], True, False)
check_hyp['hyp_check_accepted'] = np.where(check_hyp['p_value_more_alpha']==0, 'P1','P0')
display(check_hyp)
# Out:
#      hyp_names        p_value     alpha  p_value_more_alpha hyp_check_accepted
# 2  gr_11_gr_21  5.402298e-285  0.008333               False                 P1
# 3  gr_11_gr_22  9.225053e-275  0.010000               False                 P1
# 4  gr_12_gr_21  2.465262e-235  0.012500               False                 P1
# 5  gr_12_gr_22  2.483884e-228  0.016667               False                 P1
# 1  gr_11_gr_12   1.290768e-07  0.025000               False                 P1
# 6  gr_21_gr_22   9.970032e-01  0.050000                True                 P0

# %% [markdown]
# Отклоняем нулевые гипотезы до последней проверки.
# Между группами gr_11_gr_12,	gr_11_gr_22	, gr_12_gr_21, gr_12_gr_22, gr_11_gr_21 есть статистически значимая разница.
# Между группами gr_21_gr_22 статистически значимого отличия нет.

# %% [markdown]
# **Сравним уровень уверенности content между нашими когортами студентов**

# %% [markdown]
# Проверим отличается ли уровень уверенности content между когортами.
# Проверка данных на нормальность:

# %%
alpha = 0.05  # критический уровень статистической значимости

results = st.shapiro(data['content_avg'])
p_value = results[
    1
]  # второе значение в массиве результатов (с индексом 1) - p-value

print('p-значение: ', p_value)

if p_value < alpha:
    print('Отвергаем нулевую гипотезу: распределение не нормально')
else:
    print('Не получилось отвергнуть нулевую гипотезу, всё нормально')
# Out:
# p-значение:  1.2982634216325488e-32
# Отвергаем нулевую гипотезу: распределение не нормально

# %% [markdown]
# Сравнение всех групп по показателю `content_avg`

# %%
test_p = []
test_name = []
test_mwu_update('content_avg', test_p,test_name)
# Out:
# Гипотезы.
#
# H0 - Между gr_11 и gr_12 статистически значимого отличия нет.
# H1 - Между gr_11 и gr_12 есть статистически значимая разница.
#
#
# alpha: 0.050
# Среднее первой группы gr_11 : 1.515
# Среднее второй группы gr_12 : 0.149
# results.pvalue: 0.00000
# ------------------------------------------------------------
# Гипотезы.
#
# H0 - Между gr_11 и gr_21 статистически значимого отличия нет.
# H1 - Между gr_11 и gr_21 есть статистически значимая разница.
#
#
# alpha: 0.050
# Среднее первой группы gr_11 : 1.515
# Среднее второй группы gr_21 : 1.486
# results.pvalue: 0.14451
# ------------------------------------------------------------
# Гипотезы.
#
# H0 - Между gr_11 и gr_22 статистически значимого отличия нет.
# H1 - Между gr_11 и gr_22 есть статистически значимая разница.
#
#
# alpha: 0.050
# Среднее первой группы gr_11 : 1.515
# Среднее второй группы gr_22 : 0.049
# results.pvalue: 0.00000
# ------------------------------------------------------------
# Гипотезы.
#
# H0 - Между gr_12 и gr_21 статистически значимого отличия нет.
# H1 - Между gr_12 и gr_21 есть статистически значимая разница.
#
#
# alpha: 0.050
# Среднее первой группы gr_12 : 0.149
# Среднее второй группы gr_21 : 1.486
# results.pvalue: 0.00000
# ------------------------------------------------------------
# Гипотезы.
#
# H0 - Между gr_12 и gr_22 статистически значимого отличия нет.
# H1 - Между gr_12 и gr_22 есть статистически значимая разница.
#
#
# alpha: 0.050
# Среднее первой группы gr_12 : 0.149
# Среднее второй группы gr_22 : 0.049
# results.pvalue: 0.01729
# ------------------------------------------------------------
# Гипотезы.
#
# H0 - Между gr_21 и gr_22 статистически значимого отличия нет.
# H1 - Между gr_21 и gr_22 есть статистически значимая разница.
#
#
# alpha: 0.050
# Среднее первой группы gr_21 : 1.486
# Среднее второй группы gr_22 : 0.049
# results.pvalue: 0.00000
# ------------------------------------------------------------

# %%
test_name
# Out:
# ['gr_11_gr_12',
#  'gr_11_gr_21',
#  'gr_11_gr_22',
#  'gr_12_gr_21',
#  'gr_12_gr_22',
#  'gr_21_gr_22']

# %%
test_p
# Out:
# [3.900838234441522e-243,
#  0.14451278830271558,
#  4.8416982754147944e-276,
#  1.0680333283408612e-236,
#  0.01728910188947443,
#  9.281546012255198e-268]

# %%
#создадим датафрейм из p_value и добавим номер гипотезы
content_hyp = pd.DataFrame({'hyp_names':test_name,  'p_value': test_p},index=number_of_hyp)
#отсортируем от самого низкого значения p_value
content_hyp.sort_values(by = 'p_value',inplace=True)
#добавим alpha
content_hyp['alpha'] = alpha_cor
#добавим столбец с проверкой, если p_value больше alpha, то Истина
content_hyp['p_value_more_alpha'] = np.where(content_hyp['p_value']>= content_hyp['alpha'], True, False)
content_hyp['hyp_content_accepted'] = np.where(content_hyp['p_value_more_alpha']==0, 'P1','P0')
display(content_hyp)
# Out:
#      hyp_names        p_value     alpha  p_value_more_alpha  \
# 3  gr_11_gr_22  4.841698e-276  0.008333               False
# 6  gr_21_gr_22  9.281546e-268  0.010000               False
# 1  gr_11_gr_12  3.900838e-243  0.012500               False
# 4  gr_12_gr_21  1.068033e-236  0.016667               False
# 5  gr_12_gr_22   1.728910e-02  0.025000               False
# 2  gr_11_gr_21   1.445128e-01  0.050000                True
#
#   hyp_content_accepted
# 3                   P1
# 6                   P1
# 1                   P1
# 4                   P1
# 5                   P1
# 2                   P0

# %% [markdown]
# Отклоняем нулевые гипотезы до последней проверки.
# Между группами gr_11_gr_12,	gr_11_gr_22	, gr_12_gr_21, gr_12_gr_22, gr_21_gr_22 есть статистически значимая разница.
# Между группами gr_11_gr_21 статистически значимого отличия нет.

# %% [markdown]
# Объединим данные

# %%
hyp_output = check_hyp.join(content_hyp[['hyp_content_accepted']])
hyp_output = hyp_output[['hyp_names','hyp_check_accepted','hyp_content_accepted']]
hyp_output['result'] = np.where(
    (hyp_output['hyp_check_accepted']=='P0') & (hyp_output['hyp_content_accepted']=='P0'), 
    'Когорты не отличаются между собой', 'Когорты отличаются между собой по одному или двум признакам')
hyp_output
# Out:
#      hyp_names hyp_check_accepted hyp_content_accepted  \
# 2  gr_11_gr_21                 P1                   P0
# 3  gr_11_gr_22                 P1                   P1
# 4  gr_12_gr_21                 P1                   P1
# 5  gr_12_gr_22                 P1                   P1
# 1  gr_11_gr_12                 P1                   P1
# 6  gr_21_gr_22                 P0                   P1
#
#                                                         result
# 2  Когорты отличаются между собой по одному или двум признакам
# 3  Когорты отличаются между собой по одному или двум признакам
# 4  Когорты отличаются между собой по одному или двум признакам
# 5  Когорты отличаются между собой по одному или двум признакам
# 1  Когорты отличаются между собой по одному или двум признакам
# 6  Когорты отличаются между собой по одному или двум признакам

# %% [markdown]
# Между всеми сегментами есть различия по одному или двум признакам.  Оставляем границы в обозначенных уровнях.

# %% [markdown]
# ### Распределение направлений обучения среди выделенных сегментов

# %%
profession = data.pivot_table(index='profession_name', columns='cluster',values='user_id', aggfunc='nunique')
profession_prct = profession.copy()
cols = profession_prct .columns.values
profession_prct[cols] = profession_prct[cols].div(profession_prct[cols].sum(axis=1), axis=0).fillna(0)
profession_prct =profession_prct.sort_values('Cluster_1', ascending=False)
heatmapCr(profession_prct, 'Распределение студентов разных профессий по сегментам', 'Сегменты', 'Профессии', \
          fontsize=20, fmt='.0%', vmin=-0.005)

# %% [markdown]
# Максимальную эффективность показывают студенты, обучающиеся на направлениях «Системный аналитик» и «Дата инженер». Большинство студентов уже имеют аналогичный опыт работы, возможно им нужно предложить более сложный материал.
#
# Самая низкая эффективность и уверенность у студентов направлений «Аналитик данных» и «Специалист по Data Science» которые выбирают в основном новички. Возможно курсы требуют более подробного изложения материала или большей поддержки наставников.
#
# 60% неэффективных в себе студентов на курсе «Математика для анализа данных и Data Science». Возможно курс сложен для понимания и требует доработки.

# %% [markdown]
# ### Распределение разного вида опыта среди выделенных сегментов

# %% [markdown]
# Сократим количество опций для разновидностей опыта

# %%
data['background'] = data['Q2.Бэкграунд'].map(background)

# %% [markdown]
# Посмотрим как распределяется опыт внутри наших сегментов студентов

# %%
background = data.pivot_table(index='background', columns='cluster',values='user_id', aggfunc='nunique')
background_prct = background.copy()
cols = background_prct .columns.values
background_prct[cols] = background_prct[cols].div(background_prct[cols].sum(axis=1), axis=0)
background_prct =background_prct.sort_values('Cluster_1', ascending=False)
heatmapCr(background_prct, 'Распределение студентов с разным опытом по сегментам', 'Сегменты', 'Опыт', fontsize=20, \
          fmt='.0%', vmin=0.155)

# %% [markdown]
# Опытные студенты действительно демонстрируют высокую эффективность а также уверены в своих знаниях, в том числе и с опытом не в анализе данных
# Среди начинающих высокая доля тех кто обладает низкой эффективностью, но уверен в своих знаниях.

# %% [markdown]
# ### Распределение вариантов карьерной поддержки среди выделенных сегментов

# %%
groups = data[['user_id','cluster']].drop_duplicates()
answers=answers.join(groups.set_index('user_id'), on='user_id',lsuffix='not')
Q4 = answers[answers['question']=='Q4.Опции'].pivot_table(index='user_answer', values='user_id', columns='cluster',\
                                                          aggfunc='nunique').sort_values('Cluster_1', ascending=False)
Q4_prct = Q4.copy().T
cols = Q4_prct .columns.values
Q4_prct[cols] = Q4_prct[cols].div(Q4_prct[cols].sum(axis=1), axis=0)

heatmapCr(Q4_prct.T, 'Распределение ответов по вариантам карьерной поддержки', 'Сегменты', 'Ответы', \
          figsize=(10, 10), fmt='.1%', vmin=-0.005, fontsize=20)

# %% [markdown]
# Для всех категорий студентов актуальтны разные формы карьерной поддержки вне зависимости от знаний и уверенности в знаниях

# %% [markdown]
# # Вывод
#
#
# Перед нами стояла задача составить портреты студентов курсов Практикум, выделить значимые закономерности, сегментировать студентов (по 2м и более показателям), выявить особенности сегментов, сформулировать на основе данных гипотезы по улучшению выстраивания помощи студентам в достижении их целей.
# Большинство пользователей обучаются на data-analyst и data-scientist. На третьем месте Системные аналитики, дальше следуют точечные направления.
# Чуть более половины студентов оплачивают обучение с помощью государственных дотаций (1681). На втором месте с небольшим отрывом те, кто учится за свой счет (1445). Некоторые студенты переходят с государственного на собственное финансирование, возможно из-за проблем со сроками.
# Обучающихся за счет работодателя мало, всего 20 человек. Яндексу стоит потратить усилия для привлечения бизнес-клиентов.
#
# Основная цель студентов – сменить работу Большинство приходят учиться без опыта работы Записываются в карьерный трек во время обучения около 40%, а активно ищут работу я около 20% Самые востребованные опции карьерного центра: составление резюме, портфолио, навыки прохождения собеседования. Только 1% считает что им не нужна помощь.
# Различия по направлениям обучения:
#
# `Аналитик данных`(43% всех студентов) и `Аналитик данных плюс`(5%) в основном выбирают люди, которые хотят сменить область деятельности, но не имеют возможности или потребности делать это в сжатые сроки. Также курс привлекателен для собственников бизнеса и уже работающих в этой или смежной областях людей. Большинство участников ставит перед собой цель смены работы, но есть и те, кто проходит курс для совершенствования на текущем месте.
# `Аналитик данных буткемп` (0.5%) выбирают люди, которые в данный момент не имеют постоянной работы и готовы потратить много сил и времени на обучение для трудоустройства.
# `Специалист по Data Science`(33%) и`Специалист по Data Science плюс` (3%)выбирают не только люди, которые хотят сменить область деятельности (хоть их больше половины), но и имеющие опыт с целью повысить квалификацию и получить новую работу или должность. Также обучение привлекательно для владельцев бизнеса. Ученики не имеют возможности или потребности получать знания и менять работу в срочном порядке.
# Почти половина людей, выбирающих `Data Science буткемп`(0.3%) уже имеет опыт в IT и ставит целью профессиональный рост и смену работы (видимо в рамках такого роста). Можно предположить что учащиеся должны быть хорошо мотивированы и иметь высокую успеваемость.
# `Системный аналитик`(9%) привлекателен для людей с опытом больше, чем для новичков. Значительная часть учащихся ставит целью повышение квалификации. Активно ищут работу всего 15%, что может указывать на то, что большинство имеет работу, но стремится сменить компанию или должность.
#  `SQL для работы с данными и аналитикой`(4.4%) выбирают люди, которые работают в аналитике, IT или смежных областях с целью получения новых знаний и опыта.
#
# `Визуализация данных и введение в BI инструменты`(0.8%) выбирают люди с опытом работы для повышения квалификации. Треть из них не нуждается в помощи с трудоустройством, мало кто активно ищет работу. Интересно, что это самый привлекательный курс для собственников бизнеса.
#
# Курс `Инженер данных` (0.4%)выбирает больше всего людей с опытом в аналитике и других областях IT, что закономерно поскольку он адресован людям с опытом определенными и знаниями. Активно ищут работу в два раза больше людей, чем участвуют в карьерном. Видимо у многих уже есть свой карьерный план.
#
# `Математика для анализа данных` (0.3%)- дополнительный курс для прокачки имеющихся навыков и знаний. Востребован как новичками, так и специалистами для повышения квалификации.
#
# Часть опросника имеет не совсем точные формулировки:
# **Цель: сменить работу**
# Должна быть разбита на 2 категории:  1- хотят сменить область деятельности (как правило новички), 2 – хотят сменить компанию-работодателя (учатся для повышения квалификации).
# **Нашли работу в процессе обучения: нет**
# Должна быть разбита на 2 категории: 1- ищу, но не нашел, 2- не ищу.
# **Нашли работу в процессе обучения: да**
# Должна быть разбита на 2 категории: 1- искал и нашел (желательно уточнить пригодилось ли обучение), 2- уже трудоустроен и менять не собираюсь.
#
# В зависимости от вида оплаты
# Государственными программами чаще всего пользуются новички (73%) с целью сменить работу (70%). Большая часть (95%) нуждается в помощи в трудоустройстве, треть (35%) записывается в карьерный трек во время обучения. Имеют опыт в аналитике всего 10%, в других направлениях IT – 17%.
# За свой счет учится больше людей с опытом, чем по государственным программам: 20% работали в других областях IT, 21% работали в аналитике. Цель большинства – сменить работу (62%). Больше всего пользуются карьерным треком во время обучения (39%).
# За счет бизнеса учатся люди, которые хотят продвинуться по карьерной лестнице или получить повышение зарплаты (46%), улучшить свои знания (20%). Некоторые указали смену работы (33%), 12% записались в карьерный трек, 4% активно ищут работу. Это говорит о том, что в этой группе не только повышающие квалификацию за счет компании. Возможно есть люди, которым удобнее оплачивать учебу от юридического лица (например собственного ИП).
# Также неожиданным кажется что в этой категории никто не выбрал развитие собственного бизнеса (в других категориях по 2%). Нужно подробнее изучить эту группу для дальнейшего привлечения в Яндекс.
#
# Люди без опыта в IT идут на обучение с основной целью – сменить работу (76%). Видимо имеется в виду смена области деятельности. Уже имеющие опыт в анализе данных (независимо от срока) стремятся получить новые знания чтобы повысить зарплату (21% - 27%). С опытом менее 1 года заинтересованы продвинуться по карьерной лестнице (17%) и сменить работу (42%), видимо подразумевая смену работодателя. С опытом более 1 года и более 3 лет заинтересованы структурировать знания (17% и 15%) и возможно сменить работу (31% и 28%), также видимо подразумевая смену работодателя, а не область деятельности. Имеющие опыт в других направлениях IT учатся на аналитике чтобы сменить работу (49% - 55%). Они также указывают целями обучения повышение зарплаты (13%-16%), получение новых знаний (12%-16%), продвижение по карьерной лестнице (10% - 12%). Можно предположить что они изучили на собственном опыте разные специализации IT и сделали осознанный выбор будущей профессии, решили дальше развиваться в аналитике.
# Судя по данному распределению помощь с карьерой необходима людям без опыта и нужна многим людям с опытом в других направлениях IT и в меньшей мере имеющим опыт в аналитике - только 8% заявили, что не планируют участвовать в карьерном треке.
# При составлении портрета пользователей мы рассмотрели распределение опций помощи карьерного центра по направлениям обучения и не нашли зависимостей. Было предположение что эти опции могут зависеть от опыта работы.
# Запросы отличаются мало,все опции востребованы примерно одинаково. Самыми важными для всех являются навыки самопрезентации: составление резюме, оформление портфолио, прохождение собеседований. Одинаково важным все считают изучение рынка труда и своей ниши в нем: определение стратегии поиска, оценка шансов, персональная консультация. Определение профессиональной сферы больше волнует новичков, в меньшей степени опытных специалистов. Как говорить про повышение интересует специалистов больше, чем новичков. Только 1% в каждой группе считает, что помощь не нужна. Можно сделать вывод, что все опции помощи карьерного центра одинаково важны всем обучающимся, независимо от выбранной специальности и опыта работы.
#
# Для оценки студента  используется две шкалы:
# learning performance – от 0 до 1
# уверенность в знаниях content от -2 до 2
# Эффективность большинства студентов 0,7-0,8, уверенность в знаниях  1-2
# Эффективность и опыт не коррелируются между собой
# Есть интересные отличия эффективности и уверенности
# - более уверенные с опытом работы от 1 года до 3х
# - более знающие с опытом работы более 3х лет
# - более уверенные в активном поиске работы
# - более эффективные уже нашли
# - более уверенные уже записались на карьерынй трек
#
# Сформируем **4 сегмента студентов** в зависимости от уверенности  в себе и эффективности
#
# |Сегмент    | Расшифровка  | learn_perf_avg|content_avg |
# |----------|----------|------------------|---------------|
# | 11    |  Эффективные, уверенные в себе   | 0,83|1,51|
# | 12    |  Эффективные, неуверенные в себе   | 0,81|0,16|
# | 21    |  Неэффективные, уверенные в себе    |0,62|1,49|
# | 22    | Неэффективные, неуверенные в себе    |0,62|0,05|
#
#
# Распределение направлений обучения среди выделенных сегментов
# 58% - 74% доля эффективных и уверенных студентов на курсах Системный аналитик и Дата инженер
# Эти направления выбирают студенты с опытом
# Рекомендация: предложить более сложный материал.
# 60% доля студентов с низкой эффективностью на курсе Математика для анализа данных
# Курс сложен для понимания и требует доработки
# 60% доля студентов с низкой эффективностью на курсах «Аналитик данных» и «Специалист по Data Science»
# Эти направления чаще других выбирают новички
# Курсы требуют более подробного изложения материала или большей поддержки наставников.
#
# Распределние опыта по сегментам
# Самые опытные студенты действительно демонстрируют высокую эффективность а также уверены в своих знаниях.
# Среди начинающих высокая доля тех кто обладает низкой эффективностью, но уверен в своих знаниях.
# Среди студентов с опытом в других направлниях IT никто не выделяется
#
# Для всех категорий студентов актуальтны разные формы карьерной поддержки вне зависимости от знаний и уверенности в знаниях
#
#   **Гипотезы и рекомендации**
#
#   Неэффективным студентам оказывать техническую поддержку для увеличения знаний
#   Неуверенным - поддержку в виде коучевых техник, открытых собеседований, расширенной обратной связи от ревьюверов
#   Всем, кто проходит карьерный трек - оказывать равную помощь в карьерной поддержке - самые важные
#  навыки самопрезентации: составление резюме, оформление портфолио,  прохождение собеседований.
#  Для новичнов дополнительно актуально определние направления развития.
